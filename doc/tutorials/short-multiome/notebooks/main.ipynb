# %% [markdown]
# # Short tutorial: context-specific GRN inference from 10x multiome dataset
# This is a [Dictys](https://github.com/pinellolab/dictys) tutorial to reconstruct and analyze context-specific GRNs from a [10x multiome dataset on PBMC](https://www.10xgenomics.com/resources/datasets/pbmc-from-a-healthy-donor-granulocytes-removed-through-cell-sorting-10-k-1-standard-2-0-0). For a full version with details of individual steps, see tutorial [full-multiome](https://github.com/pinellolab/dictys/tree/master/doc/tutorials/full-multiome).
#
# Before running, you need to **change the runtime configurations** for your machine at [2. Network inference configuration](#2.-Network-inference-configuration) and [3. Network inference](#3.-Network-inference).
#
# If you face any issues or need any assistance, see [FAQ](https://github.com/pinellolab/dictys#faq) and [Issues](https://github.com/pinellolab/dictys#issues).
#
# By using this notebook, you imply that you have already accepted the terms of use and privacy policy on the [10x dataset webpage](https://www.10xgenomics.com/resources/datasets/pbmc-from-a-healthy-donor-granulocytes-removed-through-cell-sorting-10-k-1-standard-2-0-0). The dataset summary webpage is also available [here](https://cf.10xgenomics.com/samples/cell-arc/2.0.0/pbmc_granulocyte_sorted_10k/pbmc_granulocyte_sorted_10k_web_summary.html).

# %% [markdown]
# ## 1. Preparation of individual input files in `data` folder
# After data processing with CellRanger, you need the following files:
# * RNA read count matrix ("Filtered feature barcode matrix MEX (DIR)")
# * ATAC reads ("ATAC Position-sorted alignments (BAM)")
# * Optionally or from other softwares: cell clustering (inside "Secondary analysis outputs (DIR)")

# %%
# Removes CPU usage limit by some jupyter versions
import os
os.environ['KMP_AFFINITY'] = ''
#Create input data folder
# !mkdir ../data

# %% [markdown]
# ### expression.tsv.gz
# Read count matrix of RNA-profiled cells in compressed tsv format. Downloaded and converted from "Filtered feature barcode matrix MEX (DIR)".

# %%
# %%bash
# cd ../data
# # Download expression data in mtx.gz format
# wget -q -o /dev/null https://cf.10xgenomics.com/samples/cell-arc/2.0.0/pbmc_granulocyte_sorted_10k/pbmc_granulocyte_sorted_10k_filtered_feature_bc_matrix.tar.gz
# tar xf pbmc_granulocyte_sorted_10k_filtered_feature_bc_matrix.tar.gz
# rm pbmc_granulocyte_sorted_10k_filtered_feature_bc_matrix.tar.gz
# # Convert from mtx.gz to tsv.gz format using helper script `expression_mtx.py`.
# dictys_helper expression_mtx.py filtered_feature_bc_matrix expression.tsv.gz
# rm -Rf filtered_feature_bc_matrix
# Out:
# WARNING:root:Skipped duplicate occurrence of gene names: TBCE,LINC01238,CYB561D2,MATR3,LINC01505,HSPA14,GOLGA8M,GGT1,ARMCX5-GPRASP2,TMSB15B

# %% [markdown]
# ### bams
# This folder contains one bam file for each cell with chromatin accessibility measurement. File name should be cell name. Downloaded and converted from "ATAC Position-sorted alignments (BAM)".
# * **This step can take hours or even over a day**
# * The default setting will need ~30GB of memory for this dataset. Specify a lower `--buffer_size 1000` or smaller for `dictys_helper split_bam.sh` if you have less memory.

# %%
# %%bash
# set -eo pipefail
# cd ../data
# # Download chromatin accessibility reads in bam format
# wget -q -o /dev/null -O bams.bam https://s3-us-west-2.amazonaws.com/10x.files/samples/cell-arc/2.0.0/pbmc_granulocyte_sorted_10k/pbmc_granulocyte_sorted_10k_atac_possorted_bam.bam
# # Split bam file to individual bam files for each cell using helper script `split_bam.sh`
# dictys_helper split_bam.sh bams.bam bams --section "CB:Z:" --ref_expression expression.tsv.gz
# rm bams.bam

# %% [markdown]
# ### subsets & subsets.txt
# * subsets.txt: Names of cell subsets. For each cell subset, a GRN is reconstructed.
# * subsets: Folder containing one subfolder for each cell subset as in `subsets.txt`. Each subfolder contains two files:
#     - names_rna.txt: Names of cells that belong to this subset and have transcriptome measurement
#     - names_atac.txt: Names of cells that belong to this subset and have chromatin accessibility measurement
#     - For joint measurements of RNA and ATAC, these two files should be identical in every folder.
#
# Option 1: download the clustering from 10x "Secondary analysis outputs (DIR)":

# %%
# %%bash
# cd ../data
# wget -q -o /dev/null https://cf.10xgenomics.com/samples/cell-arc/2.0.0/pbmc_granulocyte_sorted_10k/pbmc_granulocyte_sorted_10k_analysis.tar.gz
# #Extract cell names for each cluster
# tar xf pbmc_granulocyte_sorted_10k_analysis.tar.gz
# mv analysis/clustering/gex/graphclust/clusters.csv clusters.csv
# rm -Rf pbmc_granulocyte_sorted_10k_analysis.tar.gz analysis

# %% [markdown]
# Option 2: cluster with other softwares (here [scanpy](https://scanpy-tutorials.readthedocs.io/en/latest/pbmc3k.html) below).
#
# **Note**:
# * The cell below can be hidden if you use a renderer other than jupyter (e.g. github).
# * If you don't have scanpy installed, the kernel would automatically restart to finish scanpy installation. Please continue by running this cell again for clustering.

# %% [raw]
# #Installs scanpy if not present
# a=!pip show scanpy &> /dev/null; echo $?
# a=''.join(a)
# if a=='0':
# 	print('Scanpy found. Continuing notebook execution.')
# elif a=='1':
# 	a=!pip install 'scanpy[leiden]'; echo $?
# 	a=''.join(a)
# 	if a!='0':
# 		raise RuntimeError('Installing scanpy failed.')
# 	print('Installing scanpy completed. Restarting kernel. Please continue from here.')
# 	import os
# 	os._exit(00)
# else:
# 	raise ValueError('Unknown return for: pip show scanpy')
#
# #Clustering with scanpy
# import numpy as np
# import pandas as pd
# import scanpy as sc
# adata = sc.read_10x_mtx('../data/filtered_feature_bc_matrix/',var_names='gene_symbols',cache=False)
# adata.var_names_make_unique()
# sc.pp.filter_cells(adata, min_genes=200)
# sc.pp.filter_genes(adata, min_cells=3)
# adata.var['mt'] = adata.var_names.str.startswith('MT-')  # annotate the group of mitochondrial genes as 'mt'
# sc.pp.calculate_qc_metrics(adata, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)
# sc.pl.scatter(adata, x='total_counts', y='pct_counts_mt')
# sc.pl.scatter(adata, x='total_counts', y='n_genes_by_counts')
# adata = adata[adata.obs.n_genes_by_counts < 6000, :]
# adata = adata[adata.obs.pct_counts_mt < 20, :]
# sc.pp.normalize_total(adata, target_sum=1e4)
# sc.pp.log1p(adata)
# sc.pp.highly_variable_genes(adata, min_mean=0.0125, max_mean=3, min_disp=0.5)
# sc.pl.highly_variable_genes(adata)
# adata.raw = adata
# adata = adata[:, adata.var.highly_variable]
# sc.pp.regress_out(adata, ['total_counts', 'pct_counts_mt'])
# sc.pp.scale(adata, max_value=10)
# sc.tl.pca(adata, svd_solver='arpack')
# sc.pp.neighbors(adata, n_neighbors=10, n_pcs=40)
# sc.tl.leiden(adata)
# adata.obs.leiden.to_csv('../data/clusters.csv',header=['Cluster'],index=True,index_label='Barcode')

# %% [markdown]
# Finally, reformat clusters.csv for input:

# %%
# %%bash
# cd ../data
# subsets="$(tail -n +2 clusters.csv | awk -F , '{print $2}' | sort -u)"
# echo "$subsets" | awk '{print "Subset"$1}' > subsets.txt
# for x in $subsets; do
# 	mkdir -p "subsets/Subset$x"
# 	grep ",$x"'$' clusters.csv | awk -F , '{print $1}' > "subsets/Subset$x/names_rna.txt"
# 	# RNA and ATAC barcodes are the same for joint quantifications
# 	cp "subsets/Subset$x/names_rna.txt" "subsets/Subset$x/names_atac.txt"
# done
# rm clusters.csv

# %% [markdown]
# ### Other files
# Motif, reference genome, gene transcriptional start site

# %%
# %%bash
# cd ../data
#
# # Motifs (file motifs.motif)
# # Option 1: from HOCOMOCO (https://hocomoco11.autosome.org/)
# wget -q -o /dev/null -O motifs.motif 'https://hocomoco11.autosome.org/final_bundle/hocomoco11/full/HUMAN/mono/HOCOMOCOv11_full_HUMAN_mono_homer_format_0.0001.motif'
# # Option 2: from HOMER
# # dictys_helper motif_homer.sh > motifs.motif
# # Option 3: provide your custom motifs
#
# # Reference genome (folder genome)
# # Note: You need the same reference genome version with chromatin accessibility reads
# # Option 1: download genome from HOMER
# dictys_helper genome_homer.sh hg38 genome
# # Option 2: provide your custom genome
#
# # Bed file for TSS (file gene.bed)
# # Download gtf file from ensembl
# wget -q -o /dev/null -O gene.gtf.gz http://ftp.ensembl.org/pub/release-107/gtf/homo_sapiens/Homo_sapiens.GRCh38.107.gtf.gz
# gunzip gene.gtf.gz
# # Convert to bed
# dictys_helper gene_gtf.sh gene.gtf gene.bed
# rm gene.gtf

# %% [markdown]
# ### Clean up

# %%
# !rm -Rf ../data/filtered_feature_bc_matrix

# %% [markdown]
# ## 2. Network inference configuration
# ### Generate configurations
# Please adjust them for your own machine and dataset

# %%
# %%bash
# # Generate configuration template
# rm -Rf ../makefiles
# mkdir ../makefiles
# cd ../makefiles
# dictys_helper makefile_template.sh common.mk config.mk env_none.mk static.mk
#
# # Update configurations, such as:
# # DEVICE: pytorch device, e.g. cpu, cuda:0. If you do not have a GPU, use 'cpu' and expect LONG computing time.
# # GENOME_MACS2: effective genome size for macs2. See https://deeptools.readthedocs.io/en/develop/content/feature/effectiveGenomeSize.html
# # JOINT: whether dataset is joint profiling of RNA and ATAC.
# # Other configurations include quality control thresholds, number of threads in each job, number of hidden confounders, etc.
# # They can be obtained in the full-multiome tutorial.
# dictys_helper makefile_update.py ../makefiles/config.mk '{"DEVICE": "cuda:0", "GENOME_MACS2": "hs", "JOINT": "1"}'

# %% [markdown]
# ### Validate input data

# %%
# !cd .. && dictys_helper makefile_check.py
# Out:
# Joint profile: True
# Found 11898 cells with RNA profile
# Found 24036 genes with RNA profile
# Found 11898 cells with ATAC profile
# Found 769 motifs
# Found 678 TFs
# Found 461 TFs in current dataset
# Missing 217 TFs in current dataset: ANDR,AP2A,AP2B,AP2C,AP2D,ARI3A,ARI5B,ATF6A,BARH1,BARH2,BC11A,BHA15,BHE22,BHE23,BHE40,BHE41,BMAL1,BRAC,BSH,COE1,COT1,COT2,CR3L1,CR3L2,ERR1,ERR2,ERR3,EVI1,GCR,HEN1,HMBX1,HME1,HME2,HNF6,HTF4,HXA1,HXA10,HXA11,HXA13,HXA2,HXA5,HXA7,HXA9,HXB1,HXB13,HXB2,HXB3,HXB4,HXB6,HXB7,HXB8,HXC10,HXC11,HXC12,HXC13,HXC6,HXC8,HXC9,HXD10,HXD11,HXD12,HXD13,HXD3,HXD4,HXD8,HXD9,ITF2,KAISO,MCR,MGAP,MLXPL,MYBA,MYBB,NDF1,NDF2,NF2L1,NF2L2,NFAC1,NFAC2,NFAC3,NFAC4,NGN2,NKX21,NKX22,NKX23,NKX25,NKX28,NKX31,NKX32,NKX61,NKX62,ONEC2,ONEC3,OZF,P53,P5F1B,P63,P73,PEBB,PHX2A,PHX2B,PIT1,PKNX1,PLAL1,PO2F1,PO2F2,PO2F3,PO3F1,PO3F2,PO3F3,PO3F4,PO4F1,PO4F2,PO4F3,PO5F1,PO6F1,PO6F2,PRD14,PRGR,RHXF1,RORG,RX,SMCA1,SMCA5,SRBP1,SRBP2,STA5A,STA5B,STF1,SUH,TF2LX,TF65,TF7L1,TF7L2,TFE2,THA,THA11,THB,TWST1,TYY1,TYY2,UBIP1,UNC4,Z324A,Z354A,ZBT14,ZBT17,ZBT18,ZBT48,ZBT49,ZBT7A,ZBT7B,ZEP1,ZEP2,ZF64A,ZKSC1,ZKSC3,ZN121,ZN134,ZN136,ZN140,ZN143,ZN148,ZN214,ZN219,ZN232,ZN250,ZN257,ZN260,ZN263,ZN264,ZN274,ZN281,ZN282,ZN317,ZN320,ZN322,ZN329,ZN331,ZN333,ZN335,ZN341,ZN350,ZN382,ZN384,ZN394,ZN410,ZN418,ZN423,ZN436,ZN449,ZN467,ZN490,ZN502,ZN524,ZN528,ZN547,ZN549,ZN554,ZN563,ZN582,ZN586,ZN589,ZN652,ZN667,ZN680,ZN708,ZN713,ZN740,ZN768,ZN770,ZN784,ZN816,ZSC16,ZSC22,ZSC31,ZSCA4
# Found 23533 genes with TSS information
# WARNING:root:Chromosomes not found in reference genome: chrGL000194.1,chrMT
# WARNING:root:Cannot find dynamic.mk or traj_node.h5. Skipping dynamic network inference checks.

# %% [markdown]
# ## 3. Network inference
# * **This step can take a day or longer**. You are strongly suggested to use a GPU. If it takes over a day, see [FAQ](https://github.com/pinellolab/dictys#faq) to improve speed.
# * Please adjust `-j n_jobs` for your machine. The total thread count is n_jobs*n_threads. By default n_threads=4.

# %%
# !cd ..; dictys_helper network_inference.sh -j 32 -J 1 static
# Out:
# mkdir -p tmp_static/Subset1/
# cp data/subsets/Subset1/names_rna.txt tmp_static/Subset1/names_rna.txt
# mkdir -p tmp_static/Subset10/
# cp data/subsets/Subset10/names_rna.txt tmp_static/Subset10/names_rna.txt
# mkdir -p tmp_static/Subset11/
# cp data/subsets/Subset11/names_rna.txt tmp_static/Subset11/names_rna.txt
# mkdir -p tmp_static/Subset12/
# cp data/subsets/Subset12/names_rna.txt tmp_static/Subset12/names_rna.txt
# mkdir -p tmp_static/Subset13/
# cp data/subsets/Subset13/names_rna.txt tmp_static/Subset13/names_rna.txt
# mkdir -p tmp_static/Subset14/
# cp data/subsets/Subset14/names_rna.txt tmp_static/Subset14/names_rna.txt
# mkdir -p tmp_static/Subset2/
# cp data/subsets/Subset2/names_rna.txt tmp_static/Subset2/names_rna.txt
# mkdir -p tmp_static/Subset3/
# cp data/subsets/Subset3/names_rna.txt tmp_static/Subset3/names_rna.txt
# mkdir -p tmp_static/Subset4/
# cp data/subsets/Subset4/names_rna.txt tmp_static/Subset4/names_rna.txt
# mkdir -p tmp_static/Subset5/
# cp data/subsets/Subset5/names_rna.txt tmp_static/Subset5/names_rna.txt
# mkdir -p tmp_static/Subset6/
# cp data/subsets/Subset6/names_rna.txt tmp_static/Subset6/names_rna.txt
# mkdir -p tmp_static/Subset7/
# cp data/subsets/Subset7/names_rna.txt tmp_static/Subset7/names_rna.txt
# mkdir -p tmp_static/Subset8/
# cp data/subsets/Subset8/names_rna.txt tmp_static/Subset8/names_rna.txt
# mkdir -p tmp_static/Subset9/
# cp tmp_static/Subset1/names_rna.txt tmp_static/Subset1/names_atac0.txt
# cp data/subsets/Subset9/names_rna.txt tmp_static/Subset9/names_rna.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset1/names_rna.txt tmp_static/Subset1/expression0.tsv.gz
# cp tmp_static/Subset10/names_rna.txt tmp_static/Subset10/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset10/names_rna.txt tmp_static/Subset10/expression0.tsv.gz
# cp tmp_static/Subset11/names_rna.txt tmp_static/Subset11/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset11/names_rna.txt tmp_static/Subset11/expression0.tsv.gz
# cp tmp_static/Subset12/names_rna.txt tmp_static/Subset12/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset12/names_rna.txt tmp_static/Subset12/expression0.tsv.gz
# cp tmp_static/Subset13/names_rna.txt tmp_static/Subset13/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset13/names_rna.txt tmp_static/Subset13/expression0.tsv.gz
# cp tmp_static/Subset14/names_rna.txt tmp_static/Subset14/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset14/names_rna.txt tmp_static/Subset14/expression0.tsv.gz
# cp tmp_static/Subset2/names_rna.txt tmp_static/Subset2/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset2/names_rna.txt tmp_static/Subset2/expression0.tsv.gz
# cp tmp_static/Subset3/names_rna.txt tmp_static/Subset3/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset3/names_rna.txt tmp_static/Subset3/expression0.tsv.gz
# cp tmp_static/Subset4/names_rna.txt tmp_static/Subset4/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset4/names_rna.txt tmp_static/Subset4/expression0.tsv.gz
# cp tmp_static/Subset5/names_rna.txt tmp_static/Subset5/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset5/names_rna.txt tmp_static/Subset5/expression0.tsv.gz
# cp tmp_static/Subset6/names_rna.txt tmp_static/Subset6/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset6/names_rna.txt tmp_static/Subset6/expression0.tsv.gz
# cp tmp_static/Subset7/names_rna.txt tmp_static/Subset7/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset7/names_rna.txt tmp_static/Subset7/expression0.tsv.gz
# cp tmp_static/Subset8/names_rna.txt tmp_static/Subset8/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset8/names_rna.txt tmp_static/Subset8/expression0.tsv.gz
# cp tmp_static/Subset9/names_rna.txt tmp_static/Subset9/names_atac0.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset9/names_rna.txt tmp_static/Subset9/expression0.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset14/expression0.tsv.gz tmp_static/Subset14/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset14/expression.tsv.gz tmp_static/Subset14/names_atac0.txt tmp_static/Subset14/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset13/expression0.tsv.gz tmp_static/Subset13/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset11/expression0.tsv.gz tmp_static/Subset11/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset14/names_atac.txt data/bams tmp_static/Subset14/reads.bam tmp_static/Subset14/reads.bai tmp_static/Subset14/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset13/expression.tsv.gz tmp_static/Subset13/names_atac0.txt tmp_static/Subset13/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset12/expression0.tsv.gz tmp_static/Subset12/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset9/expression0.tsv.gz tmp_static/Subset9/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset5/expression0.tsv.gz tmp_static/Subset5/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset13/names_atac.txt data/bams tmp_static/Subset13/reads.bam tmp_static/Subset13/reads.bai tmp_static/Subset13/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset10/expression0.tsv.gz tmp_static/Subset10/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset7/expression0.tsv.gz tmp_static/Subset7/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset11/expression.tsv.gz tmp_static/Subset11/names_atac0.txt tmp_static/Subset11/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset8/expression0.tsv.gz tmp_static/Subset8/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset6/expression0.tsv.gz tmp_static/Subset6/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset11/names_atac.txt data/bams tmp_static/Subset11/reads.bam tmp_static/Subset11/reads.bai tmp_static/Subset11/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset4/expression0.tsv.gz tmp_static/Subset4/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset12/expression.tsv.gz tmp_static/Subset12/names_atac0.txt tmp_static/Subset12/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset9/expression.tsv.gz tmp_static/Subset9/names_atac0.txt tmp_static/Subset9/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset12/names_atac.txt data/bams tmp_static/Subset12/reads.bam tmp_static/Subset12/reads.bai tmp_static/Subset12/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset5/expression.tsv.gz tmp_static/Subset5/names_atac0.txt tmp_static/Subset5/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset10/expression.tsv.gz tmp_static/Subset10/names_atac0.txt tmp_static/Subset10/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset9/names_atac.txt data/bams tmp_static/Subset9/reads.bam tmp_static/Subset9/reads.bai tmp_static/Subset9/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset5/names_atac.txt data/bams tmp_static/Subset5/reads.bam tmp_static/Subset5/reads.bai tmp_static/Subset5/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset3/expression0.tsv.gz tmp_static/Subset3/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset10/names_atac.txt data/bams tmp_static/Subset10/reads.bam tmp_static/Subset10/reads.bai tmp_static/Subset10/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset2/expression0.tsv.gz tmp_static/Subset2/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc qc_reads  tmp_static/Subset1/expression0.tsv.gz tmp_static/Subset1/expression.tsv.gz 50 10 0 200 100 0
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset7/expression.tsv.gz tmp_static/Subset7/names_atac0.txt tmp_static/Subset7/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset8/expression.tsv.gz tmp_static/Subset8/names_atac0.txt tmp_static/Subset8/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset7/names_atac.txt data/bams tmp_static/Subset7/reads.bam tmp_static/Subset7/reads.bai tmp_static/Subset7/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset6/expression.tsv.gz tmp_static/Subset6/names_atac0.txt tmp_static/Subset6/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset8/names_atac.txt data/bams tmp_static/Subset8/reads.bam tmp_static/Subset8/reads.bai tmp_static/Subset8/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset6/names_atac.txt data/bams tmp_static/Subset6/reads.bam tmp_static/Subset6/reads.bai tmp_static/Subset6/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset4/expression.tsv.gz tmp_static/Subset4/names_atac0.txt tmp_static/Subset4/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset4/names_atac.txt data/bams tmp_static/Subset4/reads.bam tmp_static/Subset4/reads.bai tmp_static/Subset4/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset3/expression.tsv.gz tmp_static/Subset3/names_atac0.txt tmp_static/Subset3/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset2/expression.tsv.gz tmp_static/Subset2/names_atac0.txt tmp_static/Subset2/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset3/names_atac.txt data/bams tmp_static/Subset3/reads.bam tmp_static/Subset3/reads.bai tmp_static/Subset3/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset2/names_atac.txt data/bams tmp_static/Subset2/reads.bam tmp_static/Subset2/reads.bai tmp_static/Subset2/peaks.bed hs
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  preproc selects_atac  tmp_static/Subset1/expression.tsv.gz tmp_static/Subset1/names_atac0.txt tmp_static/Subset1/names_atac.txt
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset1/names_atac.txt data/bams tmp_static/Subset1/reads.bam tmp_static/Subset1/reads.bai tmp_static/Subset1/peaks.bed hs
# [bam_sort_core] merging from 4 files and 4 in-memory blocks...
# INFO  @ Sun, 30 Oct 2022 09:07:15:
# # Command line: callpeak -t ../tmp_static/Subset13/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['../tmp_static/Subset13/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Sun, 30 Oct 2022 09:07:15: #1 read tag files...
# INFO  @ Sun, 30 Oct 2022 09:07:15: #1 read treatment tags...
# DEBUG @ Sun, 30 Oct 2022 09:07:15: Testing format BAM
# INFO  @ Sun, 30 Oct 2022 09:07:15: Detected format is: BAM
# INFO  @ Sun, 30 Oct 2022 09:07:15: * Input file is gzipped.
# INFO  @ Sun, 30 Oct 2022 09:07:18:  1000000
# INFO  @ Sun, 30 Oct 2022 09:07:21:  2000000
# INFO  @ Sun, 30 Oct 2022 09:07:24:  3000000
# INFO  @ Sun, 30 Oct 2022 09:07:27:  4000000
# INFO  @ Sun, 30 Oct 2022 09:07:30:  5000000
# INFO  @ Sun, 30 Oct 2022 09:07:31: 5160329 reads have been read.
# INFO  @ Sun, 30 Oct 2022 09:07:31: #1 tag size is determined as 49 bps
# INFO  @ Sun, 30 Oct 2022 09:07:31: #1 tag size = 49.0
# INFO  @ Sun, 30 Oct 2022 09:07:31: #1  total tags in treatment: 5160329
# INFO  @ Sun, 30 Oct 2022 09:07:31: #1 finished!
# INFO  @ Sun, 30 Oct 2022 09:07:31: #2 Build Peak Model...
# INFO  @ Sun, 30 Oct 2022 09:07:31: #2 Skipped...
# INFO  @ Sun, 30 Oct 2022 09:07:31: #2 Use 150 as fragment length
# INFO  @ Sun, 30 Oct 2022 09:07:31: #2 Sequencing ends will be shifted towards 5' by 75 bp(s)
# INFO  @ Sun, 30 Oct 2022 09:07:31: #3 Call peaks...
# INFO  @ Sun, 30 Oct 2022 09:07:31: #3 Going to call summits inside each peak ...
# INFO  @ Sun, 30 Oct 2022 09:07:31: #3 Pre-compute pvalue-qvalue table...
# DEBUG @ Sun, 30 Oct 2022 09:07:31: Start to calculate pvalue stat...
# DEBUG @ Sun, 30 Oct 2022 09:07:39: access pq hash for 11071977 times
# INFO  @ Sun, 30 Oct 2022 09:07:39: #3 Call peaks for each chromosome...
# INFO  @ Sun, 30 Oct 2022 09:08:40: #4 Write output xls file... 04_peaks.xls
# INFO  @ Sun, 30 Oct 2022 09:08:41: #4 Write peak in narrowPeak format file... 04_peaks.narrowPeak
# INFO  @ Sun, 30 Oct 2022 09:08:41: #4 Write summits bed file... 04_summits.bed
# INFO  @ Sun, 30 Oct 2022 09:08:42: Done!
#
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin wellington --nth 4 tmp_static/Subset13/reads.bam tmp_static/Subset13/reads.bai tmp_static/Subset13/peaks.bed tmp_static/Subset13/footprints.bed
# [bam_sort_core] merging from 4 files and 4 in-memory blocks...
# INFO  @ Sun, 30 Oct 2022 09:07:26:
# # Command line: callpeak -t ../tmp_static/Subset14/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['../tmp_static/Subset14/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Sun, 30 Oct 2022 09:07:26: #1 read tag files...
# INFO  @ Sun, 30 Oct 2022 09:07:26: #1 read treatment tags...
# DEBUG @ Sun, 30 Oct 2022 09:07:26: Testing format BAM
# INFO  @ Sun, 30 Oct 2022 09:07:26: Detected format is: BAM
# INFO  @ Sun, 30 Oct 2022 09:07:26: * Input file is gzipped.
# INFO  @ Sun, 30 Oct 2022 09:07:29:  1000000
# INFO  @ Sun, 30 Oct 2022 09:07:32:  2000000
# INFO  @ Sun, 30 Oct 2022 09:07:35:  3000000
# INFO  @ Sun, 30 Oct 2022 09:07:39:  4000000
# INFO  @ Sun, 30 Oct 2022 09:07:42:  5000000
# INFO  @ Sun, 30 Oct 2022 09:07:45:  6000000
# INFO  @ Sun, 30 Oct 2022 09:07:48:  7000000
# INFO  @ Sun, 30 Oct 2022 09:07:51:  8000000
# INFO  @ Sun, 30 Oct 2022 09:07:53: 8359031 reads have been read.
# INFO  @ Sun, 30 Oct 2022 09:07:53: #1 tag size is determined as 49 bps
# INFO  @ Sun, 30 Oct 2022 09:07:53: #1 tag size = 49.0
# INFO  @ Sun, 30 Oct 2022 09:07:53: #1  total tags in treatment: 8359031
# INFO  @ Sun, 30 Oct 2022 09:07:53: #1 finished!
# INFO  @ Sun, 30 Oct 2022 09:07:53: #2 Build Peak Model...
# INFO  @ Sun, 30 Oct 2022 09:07:53: #2 Skipped...
# INFO  @ Sun, 30 Oct 2022 09:07:53: #2 Use 150 as fragment length
# INFO  @ Sun, 30 Oct 2022 09:07:53: #2 Sequencing ends will be shifted towards 5' by 75 bp(s)
# INFO  @ Sun, 30 Oct 2022 09:07:53: #3 Call peaks...
# INFO  @ Sun, 30 Oct 2022 09:07:53: #3 Going to call summits inside each peak ...
# INFO  @ Sun, 30 Oct 2022 09:07:53: #3 Pre-compute pvalue-qvalue table...
# DEBUG @ Sun, 30 Oct 2022 09:07:53: Start to calculate pvalue stat...
# DEBUG @ Sun, 30 Oct 2022 09:08:07: access pq hash for 15630375 times
# INFO  @ Sun, 30 Oct 2022 09:08:07: #3 Call peaks for each chromosome...
# INFO  @ Sun, 30 Oct 2022 09:08:44: #4 Write output xls file... 04_peaks.xls
# INFO  @ Sun, 30 Oct 2022 09:08:44: #4 Write peak in narrowPeak format file... 04_peaks.narrowPeak
# INFO  @ Sun, 30 Oct 2022 09:08:44: #4 Write summits bed file... 04_summits.bed
# INFO  @ Sun, 30 Oct 2022 09:08:44: Done!
#
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin wellington --nth 4 tmp_static/Subset14/reads.bam tmp_static/Subset14/reads.bai tmp_static/Subset14/peaks.bed tmp_static/Subset14/footprints.bed
# [bam_sort_core] merging from 8 files and 4 in-memory blocks...
# INFO  @ Sun, 30 Oct 2022 09:07:48:
# # Command line: callpeak -t ../tmp_static/Subset11/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['../tmp_static/Subset11/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Sun, 30 Oct 2022 09:07:48: #1 read tag files...
# INFO  @ Sun, 30 Oct 2022 09:07:48: #1 read treatment tags...
# DEBUG @ Sun, 30 Oct 2022 09:07:48: Testing format BAM
# INFO  @ Sun, 30 Oct 2022 09:07:48: Detected format is: BAM
# INFO  @ Sun, 30 Oct 2022 09:07:48: * Input file is gzipped.
# INFO  @ Sun, 30 Oct 2022 09:07:51:  1000000
# INFO  @ Sun, 30 Oct 2022 09:07:54:  2000000
# INFO  @ Sun, 30 Oct 2022 09:07:57:  3000000
# INFO  @ Sun, 30 Oct 2022 09:08:00:  4000000
# INFO  @ Sun, 30 Oct 2022 09:08:04:  5000000
# INFO  @ Sun, 30 Oct 2022 09:08:07:  6000000
# INFO  @ Sun, 30 Oct 2022 09:08:10:  7000000
# INFO  @ Sun, 30 Oct 2022 09:08:13:  8000000
# INFO  @ Sun, 30 Oct 2022 09:08:16:  9000000
# INFO  @ Sun, 30 Oct 2022 09:08:19:  10000000
# INFO  @ Sun, 30 Oct 2022 09:08:22: 10765395 reads have been read.
# INFO  @ Sun, 30 Oct 2022 09:08:22: #1 tag size is determined as 49 bps
# INFO  @ Sun, 30 Oct 2022 09:08:22: #1 tag size = 49.0
# INFO  @ Sun, 30 Oct 2022 09:08:22: #1  total tags in treatment: 10765395
# INFO  @ Sun, 30 Oct 2022 09:08:22: #1 finished!
# INFO  @ Sun, 30 Oct 2022 09:08:22: #2 Build Peak Model...
# INFO  @ Sun, 30 Oct 2022 09:08:22: #2 Skipped...
# INFO  @ Sun, 30 Oct 2022 09:08:22: #2 Use 150 as fragment length
# INFO  @ Sun, 30 Oct 2022 09:08:22: #2 Sequencing ends will be shifted towards 5' by 75 bp(s)
# INFO  @ Sun, 30 Oct 2022 09:08:22: #3 Call peaks...
# INFO  @ Sun, 30 Oct 2022 09:08:22: #3 Going to call summits inside each peak ...
# INFO  @ Sun, 30 Oct 2022 09:08:22: #3 Pre-compute pvalue-qvalue table...
# DEBUG @ Sun, 30 Oct 2022 09:08:22: Start to calculate pvalue stat...
# DEBUG @ Sun, 30 Oct 2022 09:08:42: access pq hash for 18856970 times
# INFO  @ Sun, 30 Oct 2022 09:08:42: #3 Call peaks for each chromosome...
# INFO  @ Sun, 30 Oct 2022 09:09:21: #4 Write output xls file... 04_peaks.xls
# INFO  @ Sun, 30 Oct 2022 09:09:22: #4 Write peak in narrowPeak format file... 04_peaks.narrowPeak
# INFO  @ Sun, 30 Oct 2022 09:09:22: #4 Write summits bed file... 04_summits.bed
# INFO  @ Sun, 30 Oct 2022 09:09:22: Done!
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin wellington --nth 4 tmp_static/Subset11/reads.bam tmp_static/Subset11/reads.bai tmp_static/Subset11/peaks.bed tmp_static/Subset11/footprints.bed
# [bam_sort_core] merging from 12 files and 4 in-memory blocks...
# INFO  @ Sun, 30 Oct 2022 09:08:11:
# # Command line: callpeak -t ../tmp_static/Subset9/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['../tmp_static/Subset9/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Sun, 30 Oct 2022 09:08:11: #1 read tag files...
# INFO  @ Sun, 30 Oct 2022 09:08:11: #1 read treatment tags...
# DEBUG @ Sun, 30 Oct 2022 09:08:11: Testing format BAM
# INFO  @ Sun, 30 Oct 2022 09:08:11: Detected format is: BAM
# INFO  @ Sun, 30 Oct 2022 09:08:11: * Input file is gzipped.
# INFO  @ Sun, 30 Oct 2022 09:08:15:  1000000
# INFO  @ Sun, 30 Oct 2022 09:08:18:  2000000
# INFO  @ Sun, 30 Oct 2022 09:08:21:  3000000
# INFO  @ Sun, 30 Oct 2022 09:08:24:  4000000
# INFO  @ Sun, 30 Oct 2022 09:08:27:  5000000
# INFO  @ Sun, 30 Oct 2022 09:08:31:  6000000
# INFO  @ Sun, 30 Oct 2022 09:08:34:  7000000
# INFO  @ Sun, 30 Oct 2022 09:08:37:  8000000
# INFO  @ Sun, 30 Oct 2022 09:08:40:  9000000
# INFO  @ Sun, 30 Oct 2022 09:08:43:  10000000
# INFO  @ Sun, 30 Oct 2022 09:08:46:  11000000
# INFO  @ Sun, 30 Oct 2022 09:08:49:  12000000
# INFO  @ Sun, 30 Oct 2022 09:08:53:  13000000
# INFO  @ Sun, 30 Oct 2022 09:08:56:  14000000
# INFO  @ Sun, 30 Oct 2022 09:08:57: 14332692 reads have been read.
# INFO  @ Sun, 30 Oct 2022 09:08:57: #1 tag size is determined as 49 bps
# INFO  @ Sun, 30 Oct 2022 09:08:57: #1 tag size = 49.0
# INFO  @ Sun, 30 Oct 2022 09:08:57: #1  total tags in treatment: 14332692
# INFO  @ Sun, 30 Oct 2022 09:08:57: #1 finished!
# INFO  @ Sun, 30 Oct 2022 09:08:57: #2 Build Peak Model...
# INFO  @ Sun, 30 Oct 2022 09:08:57: #2 Skipped...
# INFO  @ Sun, 30 Oct 2022 09:08:57: #2 Use 150 as fragment length
# INFO  @ Sun, 30 Oct 2022 09:08:57: #2 Sequencing ends will be shifted towards 5' by 75 bp(s)
# INFO  @ Sun, 30 Oct 2022 09:08:57: #3 Call peaks...
# INFO  @ Sun, 30 Oct 2022 09:08:57: #3 Going to call summits inside each peak ...
# INFO  @ Sun, 30 Oct 2022 09:08:57: #3 Pre-compute pvalue-qvalue table...
# DEBUG @ Sun, 30 Oct 2022 09:08:57: Start to calculate pvalue stat...
# DEBUG @ Sun, 30 Oct 2022 09:09:23: access pq hash for 25670792 times
# INFO  @ Sun, 30 Oct 2022 09:09:23: #3 Call peaks for each chromosome...
# INFO  @ Sun, 30 Oct 2022 09:10:11: #4 Write output xls file... 04_peaks.xls
# INFO  @ Sun, 30 Oct 2022 09:10:11: #4 Write peak in narrowPeak format file... 04_peaks.narrowPeak
# INFO  @ Sun, 30 Oct 2022 09:10:12: #4 Write summits bed file... 04_summits.bed
# INFO  @ Sun, 30 Oct 2022 09:10:12: Done!
#
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin wellington --nth 4 tmp_static/Subset9/reads.bam tmp_static/Subset9/reads.bai tmp_static/Subset9/peaks.bed tmp_static/Subset9/footprints.bed
# [bam_sort_core] merging from 16 files and 4 in-memory blocks...
# INFO  @ Sun, 30 Oct 2022 09:08:32:
# # Command line: callpeak -t ../tmp_static/Subset12/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['../tmp_static/Subset12/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Sun, 30 Oct 2022 09:08:32: #1 read tag files...
# INFO  @ Sun, 30 Oct 2022 09:08:32: #1 read treatment tags...
# DEBUG @ Sun, 30 Oct 2022 09:08:32: Testing format BAM
# INFO  @ Sun, 30 Oct 2022 09:08:32: Detected format is: BAM
# INFO  @ Sun, 30 Oct 2022 09:08:32: * Input file is gzipped.
# INFO  @ Sun, 30 Oct 2022 09:08:35:  1000000
# INFO  @ Sun, 30 Oct 2022 09:08:38:  2000000
# INFO  @ Sun, 30 Oct 2022 09:08:41:  3000000
# INFO  @ Sun, 30 Oct 2022 09:08:44:  4000000
# INFO  @ Sun, 30 Oct 2022 09:08:47:  5000000
# INFO  @ Sun, 30 Oct 2022 09:08:51:  6000000
# INFO  @ Sun, 30 Oct 2022 09:08:54:  7000000
# INFO  @ Sun, 30 Oct 2022 09:08:57:  8000000
# INFO  @ Sun, 30 Oct 2022 09:09:00:  9000000
# INFO  @ Sun, 30 Oct 2022 09:09:03:  10000000
# INFO  @ Sun, 30 Oct 2022 09:09:06:  11000000
# INFO  @ Sun, 30 Oct 2022 09:09:09:  12000000
# INFO  @ Sun, 30 Oct 2022 09:09:13:  13000000
# INFO  @ Sun, 30 Oct 2022 09:09:16:  14000000
# INFO  @ Sun, 30 Oct 2022 09:09:19:  15000000
# INFO  @ Sun, 30 Oct 2022 09:09:22:  16000000
# INFO  @ Sun, 30 Oct 2022 09:09:25:  17000000
# INFO  @ Sun, 30 Oct 2022 09:09:28:  18000000
# INFO  @ Sun, 30 Oct 2022 09:09:29: 18145111 reads have been read.
# INFO  @ Sun, 30 Oct 2022 09:09:29: #1 tag size is determined as 49 bps
# INFO  @ Sun, 30 Oct 2022 09:09:29: #1 tag size = 49.0
# INFO  @ Sun, 30 Oct 2022 09:09:29: #1  total tags in treatment: 18145111
# INFO  @ Sun, 30 Oct 2022 09:09:29: #1 finished!
# INFO  @ Sun, 30 Oct 2022 09:09:29: #2 Build Peak Model...
# INFO  @ Sun, 30 Oct 2022 09:09:29: #2 Skipped...
# INFO  @ Sun, 30 Oct 2022 09:09:29: #2 Use 150 as fragment length
# INFO  @ Sun, 30 Oct 2022 09:09:29: #2 Sequencing ends will be shifted towards 5' by 75 bp(s)
# INFO  @ Sun, 30 Oct 2022 09:09:29: #3 Call peaks...
# INFO  @ Sun, 30 Oct 2022 09:09:29: #3 Going to call summits inside each peak ...
# INFO  @ Sun, 30 Oct 2022 09:09:29: #3 Pre-compute pvalue-qvalue table...
# DEBUG @ Sun, 30 Oct 2022 09:09:29: Start to calculate pvalue stat...
# DEBUG @ Sun, 30 Oct 2022 09:10:02: access pq hash for 32888100 times
# INFO  @ Sun, 30 Oct 2022 09:10:02: #3 Call peaks for each chromosome...
# INFO  @ Sun, 30 Oct 2022 09:11:03: #4 Write output xls file... 04_peaks.xls
# INFO  @ Sun, 30 Oct 2022 09:11:03: #4 Write peak in narrowPeak format file... 04_peaks.narrowPeak
# INFO  @ Sun, 30 Oct 2022 09:11:04: #4 Write summits bed file... 04_summits.bed
# INFO  @ Sun, 30 Oct 2022 09:11:04: Done!
#
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin wellington --nth 4 tmp_static/Subset12/reads.bam tmp_static/Subset12/reads.bai tmp_static/Subset12/peaks.bed tmp_static/Subset12/footprints.bed
# [bam_sort_core] merging from 20 files and 4 in-memory blocks...
# INFO  @ Sun, 30 Oct 2022 09:09:08:
# # Command line: callpeak -t ../tmp_static/Subset5/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['../tmp_static/Subset5/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Sun, 30 Oct 2022 09:09:08: #1 read tag files...
# INFO  @ Sun, 30 Oct 2022 09:09:08: #1 read treatment tags...
# DEBUG @ Sun, 30 Oct 2022 09:09:08: Testing format BAM
# INFO  @ Sun, 30 Oct 2022 09:09:08: Detected format is: BAM
# INFO  @ Sun, 30 Oct 2022 09:09:08: * Input file is gzipped.
# INFO  @ Sun, 30 Oct 2022 09:09:11:  1000000
# INFO  @ Sun, 30 Oct 2022 09:09:14:  2000000
# INFO  @ Sun, 30 Oct 2022 09:09:17:  3000000
# INFO  @ Sun, 30 Oct 2022 09:09:21:  4000000
# INFO  @ Sun, 30 Oct 2022 09:09:24:  5000000
# INFO  @ Sun, 30 Oct 2022 09:09:27:  6000000
# INFO  @ Sun, 30 Oct 2022 09:09:30:  7000000
# INFO  @ Sun, 30 Oct 2022 09:09:33:  8000000
# INFO  @ Sun, 30 Oct 2022 09:09:36:  9000000
# INFO  @ Sun, 30 Oct 2022 09:09:39:  10000000
# INFO  @ Sun, 30 Oct 2022 09:09:42:  11000000
# INFO  @ Sun, 30 Oct 2022 09:09:45:  12000000
# INFO  @ Sun, 30 Oct 2022 09:09:48:  13000000
# INFO  @ Sun, 30 Oct 2022 09:09:52:  14000000
# INFO  @ Sun, 30 Oct 2022 09:09:55:  15000000
# INFO  @ Sun, 30 Oct 2022 09:09:58:  16000000
# INFO  @ Sun, 30 Oct 2022 09:10:01:  17000000
# INFO  @ Sun, 30 Oct 2022 09:10:04:  18000000
# INFO  @ Sun, 30 Oct 2022 09:10:07:  19000000
# INFO  @ Sun, 30 Oct 2022 09:10:10:  20000000
# INFO  @ Sun, 30 Oct 2022 09:10:13:  21000000
# INFO  @ Sun, 30 Oct 2022 09:10:16:  22000000
# INFO  @ Sun, 30 Oct 2022 09:10:19:  23000000
# INFO  @ Sun, 30 Oct 2022 09:10:22:  24000000
# INFO  @ Sun, 30 Oct 2022 09:10:25:  25000000
# INFO  @ Sun, 30 Oct 2022 09:10:26: 25033750 reads have been read.
# INFO  @ Sun, 30 Oct 2022 09:10:26: #1 tag size is determined as 49 bps
# INFO  @ Sun, 30 Oct 2022 09:10:26: #1 tag size = 49.0
# INFO  @ Sun, 30 Oct 2022 09:10:26: #1  total tags in treatment: 25033750
# INFO  @ Sun, 30 Oct 2022 09:10:26: #1 finished!
# INFO  @ Sun, 30 Oct 2022 09:10:26: #2 Build Peak Model...
# INFO  @ Sun, 30 Oct 2022 09:10:26: #2 Skipped...
# INFO  @ Sun, 30 Oct 2022 09:10:26: #2 Use 150 as fragment length
# INFO  @ Sun, 30 Oct 2022 09:10:26: #2 Sequencing ends will be shifted towards 5' by 75 bp(s)
# INFO  @ Sun, 30 Oct 2022 09:10:26: #3 Call peaks...
# INFO  @ Sun, 30 Oct 2022 09:10:26: #3 Going to call summits inside each peak ...
# INFO  @ Sun, 30 Oct 2022 09:10:26: #3 Pre-compute pvalue-qvalue table...
# DEBUG @ Sun, 30 Oct 2022 09:10:26: Start to calculate pvalue stat...
# DEBUG @ Sun, 30 Oct 2022 09:11:28: access pq hash for 37142429 times
# INFO  @ Sun, 30 Oct 2022 09:11:28: #3 Call peaks for each chromosome...
# INFO  @ Sun, 30 Oct 2022 09:12:14: #4 Write output xls file... 04_peaks.xls
# INFO  @ Sun, 30 Oct 2022 09:12:14: #4 Write peak in narrowPeak format file... 04_peaks.narrowPeak
# INFO  @ Sun, 30 Oct 2022 09:12:14: #4 Write summits bed file... 04_summits.bed
# INFO  @ Sun, 30 Oct 2022 09:12:14: Done!
#
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin wellington --nth 4 tmp_static/Subset5/reads.bam tmp_static/Subset5/reads.bai tmp_static/Subset5/peaks.bed tmp_static/Subset5/footprints.bed
# [bam_sort_core] merging from 24 files and 4 in-memory blocks...
# INFO  @ Sun, 30 Oct 2022 09:09:15:
# # Command line: callpeak -t ../tmp_static/Subset10/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['../tmp_static/Subset10/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Sun, 30 Oct 2022 09:09:15: #1 read tag files...
# INFO  @ Sun, 30 Oct 2022 09:09:15: #1 read treatment tags...
# DEBUG @ Sun, 30 Oct 2022 09:09:15: Testing format BAM
# INFO  @ Sun, 30 Oct 2022 09:09:15: Detected format is: BAM
# INFO  @ Sun, 30 Oct 2022 09:09:15: * Input file is gzipped.
# INFO  @ Sun, 30 Oct 2022 09:09:19:  1000000
# INFO  @ Sun, 30 Oct 2022 09:09:22:  2000000
# INFO  @ Sun, 30 Oct 2022 09:09:25:  3000000
# INFO  @ Sun, 30 Oct 2022 09:09:28:  4000000
# INFO  @ Sun, 30 Oct 2022 09:09:31:  5000000
# INFO  @ Sun, 30 Oct 2022 09:09:34:  6000000
# INFO  @ Sun, 30 Oct 2022 09:09:37:  7000000
# INFO  @ Sun, 30 Oct 2022 09:09:40:  8000000
# INFO  @ Sun, 30 Oct 2022 09:09:44:  9000000
# INFO  @ Sun, 30 Oct 2022 09:09:47:  10000000
# INFO  @ Sun, 30 Oct 2022 09:09:50:  11000000
# INFO  @ Sun, 30 Oct 2022 09:09:53:  12000000
# INFO  @ Sun, 30 Oct 2022 09:09:56:  13000000
# INFO  @ Sun, 30 Oct 2022 09:09:59:  14000000
# INFO  @ Sun, 30 Oct 2022 09:10:02:  15000000
# INFO  @ Sun, 30 Oct 2022 09:10:05:  16000000
# INFO  @ Sun, 30 Oct 2022 09:10:09:  17000000
# INFO  @ Sun, 30 Oct 2022 09:10:12:  18000000
# INFO  @ Sun, 30 Oct 2022 09:10:15:  19000000
# INFO  @ Sun, 30 Oct 2022 09:10:18:  20000000
# INFO  @ Sun, 30 Oct 2022 09:10:21:  21000000
# INFO  @ Sun, 30 Oct 2022 09:10:24:  22000000
# INFO  @ Sun, 30 Oct 2022 09:10:27:  23000000
# INFO  @ Sun, 30 Oct 2022 09:10:30:  24000000
# INFO  @ Sun, 30 Oct 2022 09:10:33:  25000000
# INFO  @ Sun, 30 Oct 2022 09:10:36: 25843096 reads have been read.
# INFO  @ Sun, 30 Oct 2022 09:10:36: #1 tag size is determined as 49 bps
# INFO  @ Sun, 30 Oct 2022 09:10:36: #1 tag size = 49.0
# INFO  @ Sun, 30 Oct 2022 09:10:36: #1  total tags in treatment: 25843096
# INFO  @ Sun, 30 Oct 2022 09:10:36: #1 finished!
# INFO  @ Sun, 30 Oct 2022 09:10:36: #2 Build Peak Model...
# INFO  @ Sun, 30 Oct 2022 09:10:36: #2 Skipped...
# INFO  @ Sun, 30 Oct 2022 09:10:36: #2 Use 150 as fragment length
# INFO  @ Sun, 30 Oct 2022 09:10:36: #2 Sequencing ends will be shifted towards 5' by 75 bp(s)
# INFO  @ Sun, 30 Oct 2022 09:10:36: #3 Call peaks...
# INFO  @ Sun, 30 Oct 2022 09:10:36: #3 Going to call summits inside each peak ...
# INFO  @ Sun, 30 Oct 2022 09:10:36: #3 Pre-compute pvalue-qvalue table...
# DEBUG @ Sun, 30 Oct 2022 09:10:36: Start to calculate pvalue stat...
# DEBUG @ Sun, 30 Oct 2022 09:11:31: access pq hash for 43694530 times
# INFO  @ Sun, 30 Oct 2022 09:11:31: #3 Call peaks for each chromosome...
# INFO  @ Sun, 30 Oct 2022 09:12:28: #4 Write output xls file... 04_peaks.xls
# INFO  @ Sun, 30 Oct 2022 09:12:29: #4 Write peak in narrowPeak format file... 04_peaks.narrowPeak
# INFO  @ Sun, 30 Oct 2022 09:12:29: #4 Write summits bed file... 04_summits.bed
# INFO  @ Sun, 30 Oct 2022 09:12:29: Done!
#
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin wellington --nth 4 tmp_static/Subset10/reads.bam tmp_static/Subset10/reads.bai tmp_static/Subset10/peaks.bed tmp_static/Subset10/footprints.bed
# [bam_sort_core] merging from 24 files and 4 in-memory blocks...
# INFO  @ Sun, 30 Oct 2022 09:09:35:
# # Command line: callpeak -t ../tmp_static/Subset6/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['../tmp_static/Subset6/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Sun, 30 Oct 2022 09:09:35: #1 read tag files...
# INFO  @ Sun, 30 Oct 2022 09:09:35: #1 read treatment tags...
# DEBUG @ Sun, 30 Oct 2022 09:09:35: Testing format BAM
# INFO  @ Sun, 30 Oct 2022 09:09:35: Detected format is: BAM
# INFO  @ Sun, 30 Oct 2022 09:09:35: * Input file is gzipped.
# INFO  @ Sun, 30 Oct 2022 09:09:38:  1000000
# INFO  @ Sun, 30 Oct 2022 09:09:41:  2000000
# INFO  @ Sun, 30 Oct 2022 09:09:44:  3000000
# INFO  @ Sun, 30 Oct 2022 09:09:47:  4000000
# INFO  @ Sun, 30 Oct 2022 09:09:51:  5000000
# INFO  @ Sun, 30 Oct 2022 09:09:54:  6000000
# INFO  @ Sun, 30 Oct 2022 09:09:57:  7000000
# INFO  @ Sun, 30 Oct 2022 09:10:00:  8000000
# INFO  @ Sun, 30 Oct 2022 09:10:03:  9000000
# INFO  @ Sun, 30 Oct 2022 09:10:06:  10000000
# INFO  @ Sun, 30 Oct 2022 09:10:10:  11000000
# INFO  @ Sun, 30 Oct 2022 09:10:13:  12000000
# INFO  @ Sun, 30 Oct 2022 09:10:16:  13000000
# INFO  @ Sun, 30 Oct 2022 09:10:19:  14000000
# INFO  @ Sun, 30 Oct 2022 09:10:22:  15000000
# INFO  @ Sun, 30 Oct 2022 09:10:25:  16000000
# INFO  @ Sun, 30 Oct 2022 09:10:29:  17000000
# INFO  @ Sun, 30 Oct 2022 09:10:32:  18000000
# INFO  @ Sun, 30 Oct 2022 09:10:35:  19000000
# INFO  @ Sun, 30 Oct 2022 09:10:38:  20000000
# INFO  @ Sun, 30 Oct 2022 09:10:41:  21000000
# INFO  @ Sun, 30 Oct 2022 09:10:44:  22000000
# INFO  @ Sun, 30 Oct 2022 09:10:47:  23000000
# INFO  @ Sun, 30 Oct 2022 09:10:50:  24000000
# INFO  @ Sun, 30 Oct 2022 09:10:54:  25000000
# INFO  @ Sun, 30 Oct 2022 09:10:57:  26000000
# INFO  @ Sun, 30 Oct 2022 09:11:00:  27000000
# INFO  @ Sun, 30 Oct 2022 09:11:03:  28000000
# INFO  @ Sun, 30 Oct 2022 09:11:04: 28274891 reads have been read.
# INFO  @ Sun, 30 Oct 2022 09:11:05: #1 tag size is determined as 49 bps
# INFO  @ Sun, 30 Oct 2022 09:11:05: #1 tag size = 49.0
# INFO  @ Sun, 30 Oct 2022 09:11:05: #1  total tags in treatment: 28274891
# INFO  @ Sun, 30 Oct 2022 09:11:05: #1 finished!
# INFO  @ Sun, 30 Oct 2022 09:11:05: #2 Build Peak Model...
# INFO  @ Sun, 30 Oct 2022 09:11:05: #2 Skipped...
# INFO  @ Sun, 30 Oct 2022 09:11:05: #2 Use 150 as fragment length
# INFO  @ Sun, 30 Oct 2022 09:11:05: #2 Sequencing ends will be shifted towards 5' by 75 bp(s)
# INFO  @ Sun, 30 Oct 2022 09:11:05: #3 Call peaks...
# INFO  @ Sun, 30 Oct 2022 09:11:05: #3 Going to call summits inside each peak ...
# INFO  @ Sun, 30 Oct 2022 09:11:05: #3 Pre-compute pvalue-qvalue table...
# DEBUG @ Sun, 30 Oct 2022 09:11:05: Start to calculate pvalue stat...
# DEBUG @ Sun, 30 Oct 2022 09:12:16: access pq hash for 40706409 times
# INFO  @ Sun, 30 Oct 2022 09:12:16: #3 Call peaks for each chromosome...
# INFO  @ Sun, 30 Oct 2022 09:13:07: #4 Write output xls file... 04_peaks.xls
# INFO  @ Sun, 30 Oct 2022 09:13:07: #4 Write peak in narrowPeak format file... 04_peaks.narrowPeak
# INFO  @ Sun, 30 Oct 2022 09:13:08: #4 Write summits bed file... 04_summits.bed
# INFO  @ Sun, 30 Oct 2022 09:13:08: Done!
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  chromatin wellington --nth 4 tmp_static/Subset6/reads.bam tmp_static/Subset6/reads.bai tmp_static/Subset6/peaks.bed tmp_static/Subset6/footprints.bed
# [bam_sort_core] merging from 28 files and 4 in-memory blocks...
# INFO  @ Sun, 30 Oct 2022 09:09:54:
# # Command line: callpeak -t ../tmp_static/Subset7/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['../tmp_static/Subset7/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Sun, 30 Oct 2022 09:09:54: #1 read tag files...
# INFO  @ Sun, 30 Oct 2022 09:09:54: #1 read treatment tags...
# DEBUG @ Sun, 30 Oct 2022 09:09:54: Testing format BAM
# INFO  @ Sun, 30 Oct 2022 09:09:54: Detected format is: BAM
# INFO  @ Sun, 30 Oct 2022 09:09:54: * Input file is gzipped.
# INFO  @ Sun, 30 Oct 2022 09:09:57:  1000000
# INFO  @ Sun, 30 Oct 2022 09:10:00:  2000000
# INFO  @ Sun, 30 Oct 2022 09:10:03:  3000000
# INFO  @ Sun, 30 Oct 2022 09:10:06:  4000000
# INFO  @ Sun, 30 Oct 2022 09:10:09:  5000000
# INFO  @ Sun, 30 Oct 2022 09:10:12:  6000000
# INFO  @ Sun, 30 Oct 2022 09:10:16:  7000000
# INFO  @ Sun, 30 Oct 2022 09:10:19:  8000000
# INFO  @ Sun, 30 Oct 2022 09:10:22:  9000000
# INFO  @ Sun, 30 Oct 2022 09:10:25:  10000000
# INFO  @ Sun, 30 Oct 2022 09:10:28:  11000000
# INFO  @ Sun, 30 Oct 2022 09:10:31:  12000000
# INFO  @ Sun, 30 Oct 2022 09:10:34:  13000000
# INFO  @ Sun, 30 Oct 2022 09:10:37:  14000000
# INFO  @ Sun, 30 Oct 2022 09:10:40:  15000000
# INFO  @ Sun, 30 Oct 2022 09:10:44:  16000000
# INFO  @ Sun, 30 Oct 2022 09:10:47:  17000000
# INFO  @ Sun, 30 Oct 2022 09:10:50:  18000000
# INFO  @ Sun, 30 Oct 2022 09:10:53:  19000000
# INFO  @ Sun, 30 Oct 2022 09:10:56:  20000000
# INFO  @ Sun, 30 Oct 2022 09:10:59:  21000000
# INFO  @ Sun, 30 Oct 2022 09:11:02:  22000000
# ...
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset3/net_meanvar.tsv.gz tmp_static/Subset3/net_weight.tsv.gz tmp_static/Subset3/net_covfactor.tsv.gz tmp_static/Subset3/net_iweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset4/net_weight.tsv.gz tmp_static/Subset4/net_meanvar.tsv.gz tmp_static/Subset4/net_covfactor.tsv.gz tmp_static/Subset4/net_nweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset4/net_meanvar.tsv.gz tmp_static/Subset4/net_weight.tsv.gz tmp_static/Subset4/net_covfactor.tsv.gz tmp_static/Subset4/net_iweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset5/net_weight.tsv.gz tmp_static/Subset5/net_meanvar.tsv.gz tmp_static/Subset5/net_covfactor.tsv.gz tmp_static/Subset5/net_nweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset5/net_meanvar.tsv.gz tmp_static/Subset5/net_weight.tsv.gz tmp_static/Subset5/net_covfactor.tsv.gz tmp_static/Subset5/net_iweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset6/net_weight.tsv.gz tmp_static/Subset6/net_meanvar.tsv.gz tmp_static/Subset6/net_covfactor.tsv.gz tmp_static/Subset6/net_nweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset6/net_meanvar.tsv.gz tmp_static/Subset6/net_weight.tsv.gz tmp_static/Subset6/net_covfactor.tsv.gz tmp_static/Subset6/net_iweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset7/net_weight.tsv.gz tmp_static/Subset7/net_meanvar.tsv.gz tmp_static/Subset7/net_covfactor.tsv.gz tmp_static/Subset7/net_nweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset7/net_meanvar.tsv.gz tmp_static/Subset7/net_weight.tsv.gz tmp_static/Subset7/net_covfactor.tsv.gz tmp_static/Subset7/net_iweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset8/net_weight.tsv.gz tmp_static/Subset8/net_meanvar.tsv.gz tmp_static/Subset8/net_covfactor.tsv.gz tmp_static/Subset8/net_nweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset8/net_meanvar.tsv.gz tmp_static/Subset8/net_weight.tsv.gz tmp_static/Subset8/net_covfactor.tsv.gz tmp_static/Subset8/net_iweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset9/net_weight.tsv.gz tmp_static/Subset9/net_meanvar.tsv.gz tmp_static/Subset9/net_covfactor.tsv.gz tmp_static/Subset9/net_nweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset9/net_meanvar.tsv.gz tmp_static/Subset9/net_weight.tsv.gz tmp_static/Subset9/net_covfactor.tsv.gz tmp_static/Subset9/net_iweight.tsv.gz
# WARNING:246880:2022-10-30 14:52:27,763:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# WARNING:246881:2022-10-30 14:52:27,849:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# WARNING:246883:2022-10-30 14:52:28,077:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# WARNING:246874:2022-10-30 14:52:28,268:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset13/net_iweight.tsv.gz tmp_static/Subset13/net_meanvar.tsv.gz tmp_static/Subset13/net_covfactor.tsv.gz tmp_static/Subset13/net_inweight.tsv.gz
# WARNING:246892:2022-10-30 14:52:28,540:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# WARNING:246900:2022-10-30 14:52:28,870:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# WARNING:246872:2022-10-30 14:52:28,953:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# WARNING:246898:2022-10-30 14:52:29,041:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# WARNING:246877:2022-10-30 14:52:29,042:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# WARNING:246894:2022-10-30 14:52:29,113:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# WARNING:246890:2022-10-30 14:52:29,132:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# WARNING:246896:2022-10-30 14:52:29,204:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# WARNING:246886:2022-10-30 14:52:29,457:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# WARNING:246870:2022-10-30 14:52:29,622:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# WARNING:246888:2022-10-30 14:52:29,726:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# WARNING:246884:2022-10-30 14:52:29,743:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# WARNING:246984:2022-10-30 14:52:29,830:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset14/net_iweight.tsv.gz tmp_static/Subset14/net_meanvar.tsv.gz tmp_static/Subset14/net_covfactor.tsv.gz tmp_static/Subset14/net_inweight.tsv.gz
# WARNING:247142:2022-10-30 14:52:32,916:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# WARNING:246875:2022-10-30 14:52:34,667:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset11/net_iweight.tsv.gz tmp_static/Subset11/net_meanvar.tsv.gz tmp_static/Subset11/net_covfactor.tsv.gz tmp_static/Subset11/net_inweight.tsv.gz
# WARNING:247352:2022-10-30 14:52:39,571:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# WARNING:246893:2022-10-30 14:52:40,682:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset5/net_iweight.tsv.gz tmp_static/Subset5/net_meanvar.tsv.gz tmp_static/Subset5/net_covfactor.tsv.gz tmp_static/Subset5/net_inweight.tsv.gz
# WARNING:247567:2022-10-30 14:52:47,084:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# WARNING:246878:2022-10-30 14:52:49,408:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset12/net_iweight.tsv.gz tmp_static/Subset12/net_meanvar.tsv.gz tmp_static/Subset12/net_covfactor.tsv.gz tmp_static/Subset12/net_inweight.tsv.gz
# WARNING:247965:2022-10-30 14:52:58,656:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# WARNING:246891:2022-10-30 14:53:12,732:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset4/net_iweight.tsv.gz tmp_static/Subset4/net_meanvar.tsv.gz tmp_static/Subset4/net_covfactor.tsv.gz tmp_static/Subset4/net_inweight.tsv.gz
# WARNING:246889:2022-10-30 14:53:18,856:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# WARNING:248676:2022-10-30 14:53:21,543:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# WARNING:246901:2022-10-30 14:53:22,009:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# WARNING:246899:2022-10-30 14:53:22,722:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# WARNING:246871:2022-10-30 14:53:23,664:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# WARNING:246887:2022-10-30 14:53:23,863:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# WARNING:246895:2022-10-30 14:53:26,111:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset9/net_iweight.tsv.gz tmp_static/Subset9/net_meanvar.tsv.gz tmp_static/Subset9/net_covfactor.tsv.gz tmp_static/Subset9/net_inweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset3/net_iweight.tsv.gz tmp_static/Subset3/net_meanvar.tsv.gz tmp_static/Subset3/net_covfactor.tsv.gz tmp_static/Subset3/net_inweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset8/net_iweight.tsv.gz tmp_static/Subset8/net_meanvar.tsv.gz tmp_static/Subset8/net_covfactor.tsv.gz tmp_static/Subset8/net_inweight.tsv.gz
# WARNING:248944:2022-10-30 14:53:30,579:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# WARNING:248945:2022-10-30 14:53:31,627:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset2/net_iweight.tsv.gz tmp_static/Subset2/net_meanvar.tsv.gz tmp_static/Subset2/net_covfactor.tsv.gz tmp_static/Subset2/net_inweight.tsv.gz
# WARNING:248977:2022-10-30 14:53:32,033:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset6/net_iweight.tsv.gz tmp_static/Subset6/net_meanvar.tsv.gz tmp_static/Subset6/net_covfactor.tsv.gz tmp_static/Subset6/net_inweight.tsv.gz
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset1/net_iweight.tsv.gz tmp_static/Subset1/net_meanvar.tsv.gz tmp_static/Subset1/net_covfactor.tsv.gz tmp_static/Subset1/net_inweight.tsv.gz
# WARNING:249076:2022-10-30 14:53:34,869:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# WARNING:249102:2022-10-30 14:53:35,164:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# WARNING:249108:2022-10-30 14:53:36,186:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# WARNING:246873:2022-10-30 14:53:38,040:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset10/net_iweight.tsv.gz tmp_static/Subset10/net_meanvar.tsv.gz tmp_static/Subset10/net_covfactor.tsv.gz tmp_static/Subset10/net_inweight.tsv.gz
# WARNING:249471:2022-10-30 14:53:47,571:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# WARNING:246897:2022-10-30 14:53:55,338:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network normalize --nth 4 tmp_static/Subset7/net_iweight.tsv.gz tmp_static/Subset7/net_meanvar.tsv.gz tmp_static/Subset7/net_covfactor.tsv.gz tmp_static/Subset7/net_inweight.tsv.gz
# WARNING:249963:2022-10-30 14:54:04,251:~/.conda/envs/dictys/lib/python3.9/site-packages/dictys/utils/parallel.py:63:Environmental variables have different values.
# mkdir -p output/
# OPENBLAS_NUM_THREADS=1 NUMEXPR_NUM_THREADS=1 MKL_NUM_THREADS=1 OPENBLAS_MAX_THREADS=1 NUMEXPR_MAX_THREADS=1 MKL_MAX_THREADS=1 python3 -m dictys  network tofile  data tmp_static data/subsets.txt output/static.h5

# %% [markdown]
# ## 4. Network analysis
# Note: network inference depends on many factors, e.g. pseudo-randomness, randomness, and software version. Your figures may vary from those shown here.
#
# ### Regulation marker discovery based on target count & specificity between cell subsets
# First we perform global analyses with all GRNs. We can use the reconstructed context specific GRNs to find *regulation marker genes* based on their regulatory activity.

# %%
import numpy as np
import matplotlib.pyplot as plt
from dictys.plot.static import compute_spec
from dictys.plot import dotplot
from dictys.net import network

#Load networks
d0=network.from_file('../output/static.h5')

#Regulation markers based on TF regulatory activity (by target count) and its specificity
#Color map of specificity
cmap='spring_r'
#Node sizes to draw legend in dot plot
node_size_deg=[20,100,200,500]
#Transformation from target count to node size
node_size_map_deg=lambda x:x*(x<=10)+(10+(x-10)*500/10/490)*(x>10)

#Find marker genes based on regulatory activity specificity
#Arguments control how many top markers to show and the cutoffs for target count, its specificity at the most abundant cell subset, and its entropy over all cell subsets
deg,deg_spec,cpm,cpm_spec,regmarker,regmarker_state=compute_spec(d0,nmax=15,vmin=10,ncut=0.3,min_entropy=0.7)
#Draw dot plot with regulatory activity and its specificity
fig,ax=dotplot(deg.loc[regmarker].iloc[::-1],deg_spec.loc[regmarker].iloc[::-1],size_transform=node_size_map_deg,sizes=np.array(node_size_deg),cmap=cmap)

# %% [markdown]
# ### Cell type annotation with regulation markers, expression markers, and differential expression
# Combining these regulation markers with expression marker (based on logCPM) and the differential expression results from the [official page](https://cf.10xgenomics.com/samples/cell-arc/2.0.0/pbmc_granulocyte_sorted_10k/pbmc_granulocyte_sorted_10k_web_summary.html), we can annotate each cell subset with their nominated cell types.

# %%
#Expression markers based on gene expression (by CPM) and its specificity
#Node sizes to draw legend in dot plot
node_size_cpm=[20,50,100,200,500,1000]
#Transformation from CPM to node size
node_size_map_cpm=lambda x:x/5*(x<=100)+(20+(x-100)*500/10/990)*(x>100)
#Find marker genes based on expression specificity through the option base='cpm'
deg,deg_spec,cpm,cpm_spec,expmarker,expmarker_state=compute_spec(d0,base='cpm',nmax=10,vmin=50,ncut=0.3,min_entropy=0.7)
#Draw dot plot with expression and its specificity
fig,ax=dotplot(cpm.loc[expmarker].iloc[::-1],cpm_spec.loc[expmarker].iloc[::-1],size_transform=node_size_map_cpm,sizes=np.array(node_size_cpm),cmap=cmap)

# %%
#Rename cell subsets
d0.rename('s',{
	'Subset1':'Treg','Subset10':'MP','Subset11':'NK.CD56h','Subset12':'DC','Subset13':'Plasma','Subset14':'Th17',
	'Subset2':'Mono.CD14.1','Subset3':'Mono.CD14.2','Subset4':'Tnaive','Subset5':'Tmem.CD4',
	'Subset6':'NK.CD56l','Subset7':'Tmem.CD8','Subset8':'B','Subset9':'Mono.CD16'})

# %% [markdown]
# ### Replot with annotated cell types
# Here we redraw these plots for validation. Expression and regulation marker analyses carry different results. The same cell type (Mono.CD14) can be clustered into separate subsets, which may show stronger differences in regulation marker than expression marker. Some other cell type (MP) might show a few regulation marker but not any expression marker.

# %%
#Redraw of regulation marker plot
deg,deg_spec,cpm,cpm_spec,regmarker,regmarker_state=compute_spec(d0,nmax=15,vmin=10,ncut=0.3,min_entropy=0.7)
fig,ax=dotplot(deg.loc[regmarker].iloc[::-1],deg_spec.loc[regmarker].iloc[::-1],size_transform=node_size_map_deg,sizes=np.array(node_size_deg),cmap=cmap)

#Redraw of expression marker plot
deg,deg_spec,cpm,cpm_spec,expmarker,expmarker_state=compute_spec(d0,base='cpm',nmax=10,vmin=50,ncut=0.3,min_entropy=0.7)
fig,ax=dotplot(cpm.loc[expmarker].iloc[::-1],cpm_spec.loc[expmarker].iloc[::-1],size_transform=node_size_map_cpm,sizes=np.array(node_size_cpm),cmap=cmap)

# %% [markdown]
# ### Heatmap of top target genes of select TFs in their corresponding cell types
# Then we move on to investigate select regulation marker TFs. Their top target genes (by regulation strength) in the corresponding cell type may indicate their functional programs.

# %%
from dictys.plot.static import fig_heatmap_top

#TF-cell type pairs selected from the last step
tf=[('FOXP3','Treg'),
	('MAF','MP'),('MAFB','MP'),('EGR1','MP'),('PPARA','MP'),
	('SMAD3','Th17'),
	('CEBPA','Mono.CD14.1'),('CEBPB','Mono.CD14.1'),('CEBPG','Mono.CD14.1'),
	('IRF4','Mono.CD14.2'),('IRF9','Mono.CD14.2'),
	('BCL6','NK.CD56l'),
	('PRDM1','B'),('PAX5','B'),
	('ATF4','Mono.CD16'),('FOSL2','Mono.CD16')]
#Number of top targets for each TF
ntop=20
#Searching for top activated target genes only
direction=1

fig,fig_colorbar,net=fig_heatmap_top(d0,tf,ntop=ntop,direction=direction,aspect=1,gann='all')

# %%
#Only annotating select target genes
#Target genes to annotate
gann='CTLA4,IKZF1'.split(',')
#Aspect ratio
aspect=0.1

fig,fig_colorbar,net=fig_heatmap_top(d0,tf,ntop=ntop,direction=direction,gann=gann,aspect=aspect)

# %% [markdown]
# ### Differential regulation & differential expression analyses between two cell types
# From the above global-level analyses, we zoom in for two cell types to understand the differences in their programs. Lacking a HSC population, here we compare T regs and B cells as an example.
#
# Differential expression logFC is the log Fold Change in expression level (CPM+1). Differential regulation logFC is the log Fold Change in regulatory activity (target count+1). They each may highlight different genes for further investigations. So we plot these two axes together to understand their differences and similarities, and to inform downstream analyses.

# %%
from dictys.plot.static import fig_diff_scatter,fig_diff_rank

#Cell type/state names to compare in (reference, alternative) format. Here it is Treg v.s. B.
states=('B','Treg')

fig=plt.figure()
ax=fig.add_subplot(111)
data=fig_diff_scatter(d0,ax,states)

# %%
#Number of top genes to annotate on each side
ntop=20
#Find genes to annotate
annotate=np.partition(data.values,[ntop-1,-ntop],axis=0)
annotate=((data.values<=annotate[ntop-1])|(data.values>=annotate[-ntop])).any(axis=1)
annotate=list(data.index[annotate])
#Draw figure
fig=plt.figure(figsize=(12,12))
ax=fig.add_subplot(111)
data=fig_diff_scatter(d0,ax,states,annotate=annotate)

# %%
#Select genes to annotate
annotate='SPIB,IRF4,PAX5,IRF4,IRF8,NFKB2,FOXP3,GATA3,ELK1,TFE3'.split(',')
fig=plt.figure()
ax=fig.add_subplot(111)
data=fig_diff_scatter(d0,ax,states,annotate=annotate)

# %% [markdown]
# ### Integrative TF ranking
# We can also perform an integrative TF ranking using the mean logFC of both differential analyses. This can combine both information sources to improve this ranking on cell-type specificity.

# %%
fig2=fig_diff_rank(data,annotate=annotate)

# %% [markdown]
# ### Draw target gene subnetwork from a TF
# We can further zoom in for a particular TF in the relevant context and look at its targets.
#
# #### Example 1: SPIB targets in B
# As before, we first draw a large figure and annotate all genes to determine which we ultimately need.

# %%
from dictys.plot.static import fig_subnet
fig=plt.figure(figsize=(12,12))
ax=fig.add_subplot(111)
nodes,edges=fig_subnet(d0,ax,'B',regulators=['SPIB'],annotate='all')

# %%
#Select genes to annotate
annotate='SPIB,IGHM,ZNF131,WDR48,UBXN1,ADK,GABPB1,COX7C,MED17,TCL1A,FLAD1,PAPOLA,NCK2,PHACTR1,CCR6,TBC1D22A,FCRL1,FCRL2,CD52,FCRL5,PRKCB,SP110,NCOA3,CD180,PIAS1,FCHSD2,BANK1,TBC1D5,IGHD,AIDA,SP100,ABCB4,SP140,FOXO1,MALT1,CNN2,DGUOK,ADAM28,SNX2,DPH5,IGHA1,RWDD3,SMAD3,KDM4C,WTAP,FLI1,IL7,POU2AF1,FAM30A,HLA-DRA,SP140L,RPS21'.split(',')
fig=plt.figure()
ax=fig.add_subplot(111)
nodes,edges=fig_subnet(d0,ax,'B',regulators=['SPIB'],annotate=annotate)

# %% [markdown]
# #### Example 2: FOXP3 in T regs

# %%
#FOXP3 does not have many strong regulation targets identified in T regs.
#We can make the network denser to reveal weaker regulations.
#Here we set a network sparsity cutoff that assigns 2% of all edges to be present.
sparsity=0.02
fig=plt.figure(figsize=(12,12))
ax=fig.add_subplot(111)
nodes,edges=fig_subnet(d0,ax,'Treg',regulators=['FOXP3'],sparsity=sparsity,annotate='all')

# %%
#Select genes to annotate
annotate='FOXP3,CTLA4,ZFP36L2,ATP10A,PPM1B,GPR155,ARID5B,UBALD2,PTPN13,RPS15A,CD2,DUSP16,CAPG'.split(',')
fig=plt.figure()
ax=fig.add_subplot(111)
nodes,edges=fig_subnet(d0,ax,'Treg',regulators=['FOXP3'],sparsity=sparsity,annotate=annotate)

# %% [markdown]
# ### Download the inferred networks to share with collaborators and community
# Others can load the networks and re-analyze/re-draw them with Dictys

# %%
from IPython.display import FileLink
FileLink('../output/static.h5')
# Out:
# ../output/static.h5

# %% [markdown]
# ### Alternatively, export the networks into tsv files

# %%
#Folder to export networks to
output_folder='../output/static'
#Choose which sparsities (proportion of edges present) to export network
#Use None to export continuous network
sparsities=[None,0.01]
d0.export(output_folder,sparsities=sparsities)
