# %% [markdown]
# # Context specific (static) gene regulatory network (GRN) inference
# This notebooks runs the context specific GRN inference pipeline. It uses the input files prepared in `data` folder and saves context specific GRNs into a single file `output/static.h5`.
#
# The pipeline consists of several parts for platform (CPU of GPU) dependent optimization of computation speed. Each part is organized into two sections in this notebook:
# 1. The execution section runs this part for network inference. You can see the commands and the output of each command.
# 2. The command description section explains each command involved in this part.
#
# Depending on your mode of computation for pytorch (defined by `DEVICE` in `makefiles/config.mk`), each part may include more steps or should be totally skipped. **Read the instructions of each part carefully.** If you cannot find the description of a command in one part, search other parts.
#
# **You should change** `-j 32` option for `make` in every part to the number of parallel processes suitable for your machine. **It should be different** for CPU and GPU parts. Here the maximum number of cores used is `32*NTH=128`. `NTH` is set in `makefiles/config.mk`.

# %% [markdown]
# ## 1.1 CPU part 1, execution
# Here GPU is used to speed up computation. Therefore this part only infers the TF binding network that serves as a constraint for GRN inference.
#
# If you encounter errors from `make` like `No rule to make target...` or `Target 'cpu' not remade because of errors`, they can be safely ignored because these targets will be produced in CPU part 2. If you see other errors especially in peak or footprint detection steps due to low cell count for select cell subsets (typically several hundreds or lower), these errors can also be ignored and these cell subsets will be removed in the reconstructed networks.

# %%
# Removes CPU usage limit by some jupyter versions
import os
os.environ['KMP_AFFINITY'] = ''

# %%
# %%bash
# set -eo pipefail
# cd ..
# #Run CPU part of inference
# make -f makefiles/static.mk -j 32 -k cpu || true
# Out:
# mkdir -p tmp_static/Subset1/
# make: *** No rule to make target `tmp_static/Subset1/net_weight.tsv.gz', needed by `tmp_static/Subset1/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset1/net_meanvar.tsv.gz', needed by `tmp_static/Subset1/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset1/net_covfactor.tsv.gz', needed by `tmp_static/Subset1/net_nweight.tsv.gz'.
# cp data/subsets/Subset1/names_rna.txt tmp_static/Subset1/names_rna.txt
# mkdir -p tmp_static/Subset10/
# make: *** No rule to make target `tmp_static/Subset10/net_weight.tsv.gz', needed by `tmp_static/Subset10/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset10/net_meanvar.tsv.gz', needed by `tmp_static/Subset10/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset10/net_covfactor.tsv.gz', needed by `tmp_static/Subset10/net_nweight.tsv.gz'.
# mkdir -p tmp_static/Subset11/
# make: *** No rule to make target `tmp_static/Subset11/net_weight.tsv.gz', needed by `tmp_static/Subset11/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset11/net_meanvar.tsv.gz', needed by `tmp_static/Subset11/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset11/net_covfactor.tsv.gz', needed by `tmp_static/Subset11/net_nweight.tsv.gz'.
# cp data/subsets/Subset10/names_rna.txt tmp_static/Subset10/names_rna.txt
# cp data/subsets/Subset11/names_rna.txt tmp_static/Subset11/names_rna.txt
# mkdir -p tmp_static/Subset12/
# cp data/subsets/Subset12/names_rna.txt tmp_static/Subset12/names_rna.txt
# mkdir -p tmp_static/Subset13/
# make: *** No rule to make target `tmp_static/Subset12/net_weight.tsv.gz', needed by `tmp_static/Subset12/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset12/net_meanvar.tsv.gz', needed by `tmp_static/Subset12/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset12/net_covfactor.tsv.gz', needed by `tmp_static/Subset12/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset13/net_weight.tsv.gz', needed by `tmp_static/Subset13/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset13/net_meanvar.tsv.gz', needed by `tmp_static/Subset13/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset13/net_covfactor.tsv.gz', needed by `tmp_static/Subset13/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset14/net_weight.tsv.gz', needed by `tmp_static/Subset14/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset14/net_meanvar.tsv.gz', needed by `tmp_static/Subset14/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset14/net_covfactor.tsv.gz', needed by `tmp_static/Subset14/net_nweight.tsv.gz'.
# cp data/subsets/Subset13/names_rna.txt tmp_static/Subset13/names_rna.txt
# mkdir -p tmp_static/Subset14/
# cp data/subsets/Subset14/names_rna.txt tmp_static/Subset14/names_rna.txt
# mkdir -p tmp_static/Subset2/
# cp data/subsets/Subset2/names_rna.txt tmp_static/Subset2/names_rna.txt
# mkdir -p tmp_static/Subset3/
# make: *** No rule to make target `tmp_static/Subset2/net_weight.tsv.gz', needed by `tmp_static/Subset2/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset2/net_meanvar.tsv.gz', needed by `tmp_static/Subset2/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset2/net_covfactor.tsv.gz', needed by `tmp_static/Subset2/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset3/net_weight.tsv.gz', needed by `tmp_static/Subset3/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset3/net_meanvar.tsv.gz', needed by `tmp_static/Subset3/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset3/net_covfactor.tsv.gz', needed by `tmp_static/Subset3/net_nweight.tsv.gz'.
# cp data/subsets/Subset3/names_rna.txt tmp_static/Subset3/names_rna.txt
# mkdir -p tmp_static/Subset4/
# cp data/subsets/Subset4/names_rna.txt tmp_static/Subset4/names_rna.txt
# mkdir -p tmp_static/Subset5/
# mkdir -p tmp_static/Subset6/
# make: *** No rule to make target `tmp_static/Subset4/net_weight.tsv.gz', needed by `tmp_static/Subset4/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset4/net_meanvar.tsv.gz', needed by `tmp_static/Subset4/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset4/net_covfactor.tsv.gz', needed by `tmp_static/Subset4/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset5/net_weight.tsv.gz', needed by `tmp_static/Subset5/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset5/net_meanvar.tsv.gz', needed by `tmp_static/Subset5/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset5/net_covfactor.tsv.gz', needed by `tmp_static/Subset5/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset6/net_weight.tsv.gz', needed by `tmp_static/Subset6/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset6/net_meanvar.tsv.gz', needed by `tmp_static/Subset6/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset6/net_covfactor.tsv.gz', needed by `tmp_static/Subset6/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset7/net_weight.tsv.gz', needed by `tmp_static/Subset7/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset7/net_meanvar.tsv.gz', needed by `tmp_static/Subset7/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset7/net_covfactor.tsv.gz', needed by `tmp_static/Subset7/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset8/net_weight.tsv.gz', needed by `tmp_static/Subset8/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset8/net_meanvar.tsv.gz', needed by `tmp_static/Subset8/net_nweight.tsv.gz'.
# cp data/subsets/Subset5/names_rna.txt tmp_static/Subset5/names_rna.txt
# cp data/subsets/Subset6/names_rna.txt tmp_static/Subset6/names_rna.txt
# mkdir -p tmp_static/Subset7/
# cp data/subsets/Subset7/names_rna.txt tmp_static/Subset7/names_rna.txt
# mkdir -p tmp_static/Subset8/
# make: *** No rule to make target `tmp_static/Subset8/net_covfactor.tsv.gz', needed by `tmp_static/Subset8/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset9/net_weight.tsv.gz', needed by `tmp_static/Subset9/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset9/net_meanvar.tsv.gz', needed by `tmp_static/Subset9/net_nweight.tsv.gz'.
# make: *** No rule to make target `tmp_static/Subset9/net_covfactor.tsv.gz', needed by `tmp_static/Subset9/net_nweight.tsv.gz'.
# cp data/subsets/Subset8/names_rna.txt tmp_static/Subset8/names_rna.txt
# mkdir -p tmp_static/Subset9/
# cp data/subsets/Subset9/names_rna.txt tmp_static/Subset9/names_rna.txt
# cp tmp_static/Subset1/names_rna.txt tmp_static/Subset1/names_atac0.txt
# python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset1/names_rna.txt tmp_static/Subset1/expression0.tsv.gz
# cp tmp_static/Subset10/names_rna.txt tmp_static/Subset10/names_atac0.txt
# python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset10/names_rna.txt tmp_static/Subset10/expression0.tsv.gz
# cp tmp_static/Subset11/names_rna.txt tmp_static/Subset11/names_atac0.txt
# python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset11/names_rna.txt tmp_static/Subset11/expression0.tsv.gz
# cp tmp_static/Subset12/names_rna.txt tmp_static/Subset12/names_atac0.txt
# python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset12/names_rna.txt tmp_static/Subset12/expression0.tsv.gz
# cp tmp_static/Subset13/names_rna.txt tmp_static/Subset13/names_atac0.txt
# python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset13/names_rna.txt tmp_static/Subset13/expression0.tsv.gz
# cp tmp_static/Subset14/names_rna.txt tmp_static/Subset14/names_atac0.txt
# python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset14/names_rna.txt tmp_static/Subset14/expression0.tsv.gz
# cp tmp_static/Subset2/names_rna.txt tmp_static/Subset2/names_atac0.txt
# python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset2/names_rna.txt tmp_static/Subset2/expression0.tsv.gz
# cp tmp_static/Subset3/names_rna.txt tmp_static/Subset3/names_atac0.txt
# python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset3/names_rna.txt tmp_static/Subset3/expression0.tsv.gz
# cp tmp_static/Subset4/names_rna.txt tmp_static/Subset4/names_atac0.txt
# python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset4/names_rna.txt tmp_static/Subset4/expression0.tsv.gz
# cp tmp_static/Subset5/names_rna.txt tmp_static/Subset5/names_atac0.txt
# python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset5/names_rna.txt tmp_static/Subset5/expression0.tsv.gz
# cp tmp_static/Subset6/names_rna.txt tmp_static/Subset6/names_atac0.txt
# python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset6/names_rna.txt tmp_static/Subset6/expression0.tsv.gz
# cp tmp_static/Subset7/names_rna.txt tmp_static/Subset7/names_atac0.txt
# python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset7/names_rna.txt tmp_static/Subset7/expression0.tsv.gz
# cp tmp_static/Subset8/names_rna.txt tmp_static/Subset8/names_atac0.txt
# python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset8/names_rna.txt tmp_static/Subset8/expression0.tsv.gz
# cp tmp_static/Subset9/names_rna.txt tmp_static/Subset9/names_atac0.txt
# python3 -m dictys  preproc selects_rna  data/expression.tsv.gz tmp_static/Subset9/names_rna.txt tmp_static/Subset9/expression0.tsv.gz
# python3 -m dictys  preproc qc_reads  tmp_static/Subset13/expression0.tsv.gz tmp_static/Subset13/expression.tsv.gz 50 10 0 200 100 0
# python3 -m dictys  preproc qc_reads  tmp_static/Subset14/expression0.tsv.gz tmp_static/Subset14/expression.tsv.gz 50 10 0 200 100 0
# python3 -m dictys  preproc selects_atac  tmp_static/Subset13/expression.tsv.gz tmp_static/Subset13/names_atac0.txt tmp_static/Subset13/names_atac.txt
# python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset13/names_atac.txt data/bams tmp_static/Subset13/reads.bam tmp_static/Subset13/reads.bai tmp_static/Subset13/peaks.bed hs
# python3 -m dictys  preproc qc_reads  tmp_static/Subset12/expression0.tsv.gz tmp_static/Subset12/expression.tsv.gz 50 10 0 200 100 0
# python3 -m dictys  preproc qc_reads  tmp_static/Subset11/expression0.tsv.gz tmp_static/Subset11/expression.tsv.gz 50 10 0 200 100 0
# python3 -m dictys  preproc selects_atac  tmp_static/Subset14/expression.tsv.gz tmp_static/Subset14/names_atac0.txt tmp_static/Subset14/names_atac.txt
# python3 -m dictys  preproc qc_reads  tmp_static/Subset10/expression0.tsv.gz tmp_static/Subset10/expression.tsv.gz 50 10 0 200 100 0
# python3 -m dictys  preproc qc_reads  tmp_static/Subset9/expression0.tsv.gz tmp_static/Subset9/expression.tsv.gz 50 10 0 200 100 0
# python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset14/names_atac.txt data/bams tmp_static/Subset14/reads.bam tmp_static/Subset14/reads.bai tmp_static/Subset14/peaks.bed hs
# python3 -m dictys  preproc qc_reads  tmp_static/Subset6/expression0.tsv.gz tmp_static/Subset6/expression.tsv.gz 50 10 0 200 100 0
# python3 -m dictys  preproc qc_reads  tmp_static/Subset5/expression0.tsv.gz tmp_static/Subset5/expression.tsv.gz 50 10 0 200 100 0
# python3 -m dictys  preproc qc_reads  tmp_static/Subset7/expression0.tsv.gz tmp_static/Subset7/expression.tsv.gz 50 10 0 200 100 0
# python3 -m dictys  preproc qc_reads  tmp_static/Subset4/expression0.tsv.gz tmp_static/Subset4/expression.tsv.gz 50 10 0 200 100 0
# python3 -m dictys  preproc qc_reads  tmp_static/Subset8/expression0.tsv.gz tmp_static/Subset8/expression.tsv.gz 50 10 0 200 100 0
# python3 -m dictys  preproc selects_atac  tmp_static/Subset11/expression.tsv.gz tmp_static/Subset11/names_atac0.txt tmp_static/Subset11/names_atac.txt
# python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset11/names_atac.txt data/bams tmp_static/Subset11/reads.bam tmp_static/Subset11/reads.bai tmp_static/Subset11/peaks.bed hs
# python3 -m dictys  preproc selects_atac  tmp_static/Subset12/expression.tsv.gz tmp_static/Subset12/names_atac0.txt tmp_static/Subset12/names_atac.txt
# python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset12/names_atac.txt data/bams tmp_static/Subset12/reads.bam tmp_static/Subset12/reads.bai tmp_static/Subset12/peaks.bed hs
# python3 -m dictys  preproc selects_atac  tmp_static/Subset10/expression.tsv.gz tmp_static/Subset10/names_atac0.txt tmp_static/Subset10/names_atac.txt
# python3 -m dictys  preproc selects_atac  tmp_static/Subset9/expression.tsv.gz tmp_static/Subset9/names_atac0.txt tmp_static/Subset9/names_atac.txt
# python3 -m dictys  preproc qc_reads  tmp_static/Subset3/expression0.tsv.gz tmp_static/Subset3/expression.tsv.gz 50 10 0 200 100 0
# python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset10/names_atac.txt data/bams tmp_static/Subset10/reads.bam tmp_static/Subset10/reads.bai tmp_static/Subset10/peaks.bed hs
# python3 -m dictys  preproc selects_atac  tmp_static/Subset5/expression.tsv.gz tmp_static/Subset5/names_atac0.txt tmp_static/Subset5/names_atac.txt
# python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset9/names_atac.txt data/bams tmp_static/Subset9/reads.bam tmp_static/Subset9/reads.bai tmp_static/Subset9/peaks.bed hs
# python3 -m dictys  preproc qc_reads  tmp_static/Subset2/expression0.tsv.gz tmp_static/Subset2/expression.tsv.gz 50 10 0 200 100 0
# python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset5/names_atac.txt data/bams tmp_static/Subset5/reads.bam tmp_static/Subset5/reads.bai tmp_static/Subset5/peaks.bed hs
# python3 -m dictys  preproc qc_reads  tmp_static/Subset1/expression0.tsv.gz tmp_static/Subset1/expression.tsv.gz 50 10 0 200 100 0
# python3 -m dictys  preproc selects_atac  tmp_static/Subset6/expression.tsv.gz tmp_static/Subset6/names_atac0.txt tmp_static/Subset6/names_atac.txt
# python3 -m dictys  preproc selects_atac  tmp_static/Subset8/expression.tsv.gz tmp_static/Subset8/names_atac0.txt tmp_static/Subset8/names_atac.txt
# python3 -m dictys  preproc selects_atac  tmp_static/Subset7/expression.tsv.gz tmp_static/Subset7/names_atac0.txt tmp_static/Subset7/names_atac.txt
# python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset6/names_atac.txt data/bams tmp_static/Subset6/reads.bam tmp_static/Subset6/reads.bai tmp_static/Subset6/peaks.bed hs
# python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset8/names_atac.txt data/bams tmp_static/Subset8/reads.bam tmp_static/Subset8/reads.bai tmp_static/Subset8/peaks.bed hs
# python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset7/names_atac.txt data/bams tmp_static/Subset7/reads.bam tmp_static/Subset7/reads.bai tmp_static/Subset7/peaks.bed hs
# python3 -m dictys  preproc selects_atac  tmp_static/Subset4/expression.tsv.gz tmp_static/Subset4/names_atac0.txt tmp_static/Subset4/names_atac.txt
# python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset4/names_atac.txt data/bams tmp_static/Subset4/reads.bam tmp_static/Subset4/reads.bai tmp_static/Subset4/peaks.bed hs
# python3 -m dictys  preproc selects_atac  tmp_static/Subset3/expression.tsv.gz tmp_static/Subset3/names_atac0.txt tmp_static/Subset3/names_atac.txt
# python3 -m dictys  preproc selects_atac  tmp_static/Subset2/expression.tsv.gz tmp_static/Subset2/names_atac0.txt tmp_static/Subset2/names_atac.txt
# python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset3/names_atac.txt data/bams tmp_static/Subset3/reads.bam tmp_static/Subset3/reads.bai tmp_static/Subset3/peaks.bed hs
# python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset2/names_atac.txt data/bams tmp_static/Subset2/reads.bam tmp_static/Subset2/reads.bai tmp_static/Subset2/peaks.bed hs
# python3 -m dictys  preproc selects_atac  tmp_static/Subset1/expression.tsv.gz tmp_static/Subset1/names_atac0.txt tmp_static/Subset1/names_atac.txt
# python3 -m dictys  chromatin macs2 --nth 4 tmp_static/Subset1/names_atac.txt data/bams tmp_static/Subset1/reads.bam tmp_static/Subset1/reads.bai tmp_static/Subset1/peaks.bed hs
# [bam_sort_core] merging from 4 files and 4 in-memory blocks...
# INFO  @ Wed, 24 Aug 2022 13:17:58:
# # Command line: callpeak -t tmp_static/Subset13/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['tmp_static/Subset13/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Wed, 24 Aug 2022 13:17:58: #1 read tag files...
# INFO  @ Wed, 24 Aug 2022 13:17:58: #1 read treatment tags...
# DEBUG @ Wed, 24 Aug 2022 13:17:58: Testing format BAM
# INFO  @ Wed, 24 Aug 2022 13:17:58: Detected format is: BAM
# INFO  @ Wed, 24 Aug 2022 13:17:58: * Input file is gzipped.
# INFO  @ Wed, 24 Aug 2022 13:18:02:  1000000
# INFO  @ Wed, 24 Aug 2022 13:18:05:  2000000
# INFO  @ Wed, 24 Aug 2022 13:18:08:  3000000
# INFO  @ Wed, 24 Aug 2022 13:18:11:  4000000
# INFO  @ Wed, 24 Aug 2022 13:18:15:  5000000
# INFO  @ Wed, 24 Aug 2022 13:18:15: 5160329 reads have been read.
# INFO  @ Wed, 24 Aug 2022 13:18:15: #1 tag size is determined as 49 bps
# INFO  @ Wed, 24 Aug 2022 13:18:15: #1 tag size = 49.0
# INFO  @ Wed, 24 Aug 2022 13:18:15: #1  total tags in treatment: 5160329
# INFO  @ Wed, 24 Aug 2022 13:18:15: #1 finished!
# INFO  @ Wed, 24 Aug 2022 13:18:15: #2 Build Peak Model...
# INFO  @ Wed, 24 Aug 2022 13:18:15: #2 Skipped...
# INFO  @ Wed, 24 Aug 2022 13:18:15: #2 Use 150 as fragment length
# INFO  @ Wed, 24 Aug 2022 13:18:15: #2 Sequencing ends will be shifted towards 5' by 75 bp(s)
# INFO  @ Wed, 24 Aug 2022 13:18:15: #3 Call peaks...
# INFO  @ Wed, 24 Aug 2022 13:18:15: #3 Going to call summits inside each peak ...
# INFO  @ Wed, 24 Aug 2022 13:18:15: #3 Pre-compute pvalue-qvalue table...
# DEBUG @ Wed, 24 Aug 2022 13:18:15: Start to calculate pvalue stat...
# DEBUG @ Wed, 24 Aug 2022 13:18:24: access pq hash for 11071977 times
# INFO  @ Wed, 24 Aug 2022 13:18:24: #3 Call peaks for each chromosome...
# INFO  @ Wed, 24 Aug 2022 13:19:27: #4 Write output xls file... 04_peaks.xls
# INFO  @ Wed, 24 Aug 2022 13:19:28: #4 Write peak in narrowPeak format file... 04_peaks.narrowPeak
# INFO  @ Wed, 24 Aug 2022 13:19:28: #4 Write summits bed file... 04_summits.bed
# INFO  @ Wed, 24 Aug 2022 13:19:28: Done!
#
# python3 -m dictys  chromatin wellington --nth 4 tmp_static/Subset13/reads.bam tmp_static/Subset13/reads.bai tmp_static/Subset13/peaks.bed tmp_static/Subset13/footprints.bed
# [bam_sort_core] merging from 4 files and 4 in-memory blocks...
# INFO  @ Wed, 24 Aug 2022 13:18:13:
# # Command line: callpeak -t tmp_static/Subset14/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['tmp_static/Subset14/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Wed, 24 Aug 2022 13:18:13: #1 read tag files...
# INFO  @ Wed, 24 Aug 2022 13:18:13: #1 read treatment tags...
# DEBUG @ Wed, 24 Aug 2022 13:18:13: Testing format BAM
# INFO  @ Wed, 24 Aug 2022 13:18:13: Detected format is: BAM
# INFO  @ Wed, 24 Aug 2022 13:18:13: * Input file is gzipped.
# INFO  @ Wed, 24 Aug 2022 13:18:16:  1000000
# INFO  @ Wed, 24 Aug 2022 13:18:19:  2000000
# INFO  @ Wed, 24 Aug 2022 13:18:22:  3000000
# INFO  @ Wed, 24 Aug 2022 13:18:26:  4000000
# INFO  @ Wed, 24 Aug 2022 13:18:29:  5000000
# INFO  @ Wed, 24 Aug 2022 13:18:32:  6000000
# INFO  @ Wed, 24 Aug 2022 13:18:35:  7000000
# INFO  @ Wed, 24 Aug 2022 13:18:39:  8000000
# INFO  @ Wed, 24 Aug 2022 13:18:40: 8359031 reads have been read.
# INFO  @ Wed, 24 Aug 2022 13:18:40: #1 tag size is determined as 49 bps
# INFO  @ Wed, 24 Aug 2022 13:18:40: #1 tag size = 49.0
# INFO  @ Wed, 24 Aug 2022 13:18:40: #1  total tags in treatment: 8359031
# INFO  @ Wed, 24 Aug 2022 13:18:40: #1 finished!
# INFO  @ Wed, 24 Aug 2022 13:18:40: #2 Build Peak Model...
# INFO  @ Wed, 24 Aug 2022 13:18:40: #2 Skipped...
# INFO  @ Wed, 24 Aug 2022 13:18:40: #2 Use 150 as fragment length
# INFO  @ Wed, 24 Aug 2022 13:18:40: #2 Sequencing ends will be shifted towards 5' by 75 bp(s)
# INFO  @ Wed, 24 Aug 2022 13:18:40: #3 Call peaks...
# INFO  @ Wed, 24 Aug 2022 13:18:40: #3 Going to call summits inside each peak ...
# INFO  @ Wed, 24 Aug 2022 13:18:40: #3 Pre-compute pvalue-qvalue table...
# DEBUG @ Wed, 24 Aug 2022 13:18:40: Start to calculate pvalue stat...
# DEBUG @ Wed, 24 Aug 2022 13:18:54: access pq hash for 15630375 times
# INFO  @ Wed, 24 Aug 2022 13:18:54: #3 Call peaks for each chromosome...
# INFO  @ Wed, 24 Aug 2022 13:19:31: #4 Write output xls file... 04_peaks.xls
# INFO  @ Wed, 24 Aug 2022 13:19:31: #4 Write peak in narrowPeak format file... 04_peaks.narrowPeak
# INFO  @ Wed, 24 Aug 2022 13:19:32: #4 Write summits bed file... 04_summits.bed
# INFO  @ Wed, 24 Aug 2022 13:19:32: Done!
#
# python3 -m dictys  chromatin wellington --nth 4 tmp_static/Subset14/reads.bam tmp_static/Subset14/reads.bai tmp_static/Subset14/peaks.bed tmp_static/Subset14/footprints.bed
# [bam_sort_core] merging from 8 files and 4 in-memory blocks...
# INFO  @ Wed, 24 Aug 2022 13:18:34:
# # Command line: callpeak -t tmp_static/Subset11/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['tmp_static/Subset11/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Wed, 24 Aug 2022 13:18:34: #1 read tag files...
# INFO  @ Wed, 24 Aug 2022 13:18:34: #1 read treatment tags...
# DEBUG @ Wed, 24 Aug 2022 13:18:34: Testing format BAM
# INFO  @ Wed, 24 Aug 2022 13:18:34: Detected format is: BAM
# INFO  @ Wed, 24 Aug 2022 13:18:34: * Input file is gzipped.
# INFO  @ Wed, 24 Aug 2022 13:18:37:  1000000
# INFO  @ Wed, 24 Aug 2022 13:18:40:  2000000
# INFO  @ Wed, 24 Aug 2022 13:18:43:  3000000
# INFO  @ Wed, 24 Aug 2022 13:18:46:  4000000
# INFO  @ Wed, 24 Aug 2022 13:18:49:  5000000
# INFO  @ Wed, 24 Aug 2022 13:18:53:  6000000
# INFO  @ Wed, 24 Aug 2022 13:18:56:  7000000
# INFO  @ Wed, 24 Aug 2022 13:18:59:  8000000
# INFO  @ Wed, 24 Aug 2022 13:19:02:  9000000
# INFO  @ Wed, 24 Aug 2022 13:19:05:  10000000
# INFO  @ Wed, 24 Aug 2022 13:19:08: 10765395 reads have been read.
# INFO  @ Wed, 24 Aug 2022 13:19:08: #1 tag size is determined as 49 bps
# INFO  @ Wed, 24 Aug 2022 13:19:08: #1 tag size = 49.0
# INFO  @ Wed, 24 Aug 2022 13:19:08: #1  total tags in treatment: 10765395
# INFO  @ Wed, 24 Aug 2022 13:19:08: #1 finished!
# INFO  @ Wed, 24 Aug 2022 13:19:08: #2 Build Peak Model...
# INFO  @ Wed, 24 Aug 2022 13:19:08: #2 Skipped...
# INFO  @ Wed, 24 Aug 2022 13:19:08: #2 Use 150 as fragment length
# INFO  @ Wed, 24 Aug 2022 13:19:08: #2 Sequencing ends will be shifted towards 5' by 75 bp(s)
# INFO  @ Wed, 24 Aug 2022 13:19:08: #3 Call peaks...
# INFO  @ Wed, 24 Aug 2022 13:19:08: #3 Going to call summits inside each peak ...
# INFO  @ Wed, 24 Aug 2022 13:19:08: #3 Pre-compute pvalue-qvalue table...
# DEBUG @ Wed, 24 Aug 2022 13:19:08: Start to calculate pvalue stat...
# DEBUG @ Wed, 24 Aug 2022 13:19:28: access pq hash for 18856970 times
# INFO  @ Wed, 24 Aug 2022 13:19:29: #3 Call peaks for each chromosome...
# INFO  @ Wed, 24 Aug 2022 13:20:07: #4 Write output xls file... 04_peaks.xls
# INFO  @ Wed, 24 Aug 2022 13:20:07: #4 Write peak in narrowPeak format file... 04_peaks.narrowPeak
# INFO  @ Wed, 24 Aug 2022 13:20:08: #4 Write summits bed file... 04_summits.bed
# INFO  @ Wed, 24 Aug 2022 13:20:08: Done!
#
# python3 -m dictys  chromatin wellington --nth 4 tmp_static/Subset11/reads.bam tmp_static/Subset11/reads.bai tmp_static/Subset11/peaks.bed tmp_static/Subset11/footprints.bed
# [bam_sort_core] merging from 12 files and 4 in-memory blocks...
# INFO  @ Wed, 24 Aug 2022 13:19:00:
# # Command line: callpeak -t tmp_static/Subset9/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['tmp_static/Subset9/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Wed, 24 Aug 2022 13:19:00: #1 read tag files...
# INFO  @ Wed, 24 Aug 2022 13:19:00: #1 read treatment tags...
# DEBUG @ Wed, 24 Aug 2022 13:19:00: Testing format BAM
# INFO  @ Wed, 24 Aug 2022 13:19:00: Detected format is: BAM
# INFO  @ Wed, 24 Aug 2022 13:19:00: * Input file is gzipped.
# INFO  @ Wed, 24 Aug 2022 13:19:03:  1000000
# INFO  @ Wed, 24 Aug 2022 13:19:06:  2000000
# INFO  @ Wed, 24 Aug 2022 13:19:09:  3000000
# INFO  @ Wed, 24 Aug 2022 13:19:12:  4000000
# INFO  @ Wed, 24 Aug 2022 13:19:15:  5000000
# INFO  @ Wed, 24 Aug 2022 13:19:18:  6000000
# INFO  @ Wed, 24 Aug 2022 13:19:22:  7000000
# INFO  @ Wed, 24 Aug 2022 13:19:25:  8000000
# INFO  @ Wed, 24 Aug 2022 13:19:29:  9000000
# INFO  @ Wed, 24 Aug 2022 13:19:32:  10000000
# INFO  @ Wed, 24 Aug 2022 13:19:35:  11000000
# INFO  @ Wed, 24 Aug 2022 13:19:38:  12000000
# INFO  @ Wed, 24 Aug 2022 13:19:41:  13000000
# INFO  @ Wed, 24 Aug 2022 13:19:44:  14000000
# INFO  @ Wed, 24 Aug 2022 13:19:45: 14332692 reads have been read.
# INFO  @ Wed, 24 Aug 2022 13:19:46: #1 tag size is determined as 49 bps
# INFO  @ Wed, 24 Aug 2022 13:19:46: #1 tag size = 49.0
# INFO  @ Wed, 24 Aug 2022 13:19:46: #1  total tags in treatment: 14332692
# INFO  @ Wed, 24 Aug 2022 13:19:46: #1 finished!
# INFO  @ Wed, 24 Aug 2022 13:19:46: #2 Build Peak Model...
# INFO  @ Wed, 24 Aug 2022 13:19:46: #2 Skipped...
# INFO  @ Wed, 24 Aug 2022 13:19:46: #2 Use 150 as fragment length
# INFO  @ Wed, 24 Aug 2022 13:19:46: #2 Sequencing ends will be shifted towards 5' by 75 bp(s)
# INFO  @ Wed, 24 Aug 2022 13:19:46: #3 Call peaks...
# INFO  @ Wed, 24 Aug 2022 13:19:46: #3 Going to call summits inside each peak ...
# INFO  @ Wed, 24 Aug 2022 13:19:46: #3 Pre-compute pvalue-qvalue table...
# DEBUG @ Wed, 24 Aug 2022 13:19:46: Start to calculate pvalue stat...
# DEBUG @ Wed, 24 Aug 2022 13:20:11: access pq hash for 25670792 times
# INFO  @ Wed, 24 Aug 2022 13:20:11: #3 Call peaks for each chromosome...
# INFO  @ Wed, 24 Aug 2022 13:20:59: #4 Write output xls file... 04_peaks.xls
# INFO  @ Wed, 24 Aug 2022 13:21:00: #4 Write peak in narrowPeak format file... 04_peaks.narrowPeak
# INFO  @ Wed, 24 Aug 2022 13:21:00: #4 Write summits bed file... 04_summits.bed
# INFO  @ Wed, 24 Aug 2022 13:21:00: Done!
#
# python3 -m dictys  chromatin wellington --nth 4 tmp_static/Subset9/reads.bam tmp_static/Subset9/reads.bai tmp_static/Subset9/peaks.bed tmp_static/Subset9/footprints.bed
# [bam_sort_core] merging from 16 files and 4 in-memory blocks...
# INFO  @ Wed, 24 Aug 2022 13:19:14:
# # Command line: callpeak -t tmp_static/Subset12/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['tmp_static/Subset12/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Wed, 24 Aug 2022 13:19:14: #1 read tag files...
# INFO  @ Wed, 24 Aug 2022 13:19:14: #1 read treatment tags...
# DEBUG @ Wed, 24 Aug 2022 13:19:14: Testing format BAM
# INFO  @ Wed, 24 Aug 2022 13:19:14: Detected format is: BAM
# INFO  @ Wed, 24 Aug 2022 13:19:14: * Input file is gzipped.
# INFO  @ Wed, 24 Aug 2022 13:19:17:  1000000
# INFO  @ Wed, 24 Aug 2022 13:19:20:  2000000
# INFO  @ Wed, 24 Aug 2022 13:19:23:  3000000
# INFO  @ Wed, 24 Aug 2022 13:19:27:  4000000
# INFO  @ Wed, 24 Aug 2022 13:19:30:  5000000
# INFO  @ Wed, 24 Aug 2022 13:19:33:  6000000
# INFO  @ Wed, 24 Aug 2022 13:19:36:  7000000
# INFO  @ Wed, 24 Aug 2022 13:19:39:  8000000
# INFO  @ Wed, 24 Aug 2022 13:19:42:  9000000
# INFO  @ Wed, 24 Aug 2022 13:19:45:  10000000
# INFO  @ Wed, 24 Aug 2022 13:19:48:  11000000
# INFO  @ Wed, 24 Aug 2022 13:19:52:  12000000
# INFO  @ Wed, 24 Aug 2022 13:19:55:  13000000
# INFO  @ Wed, 24 Aug 2022 13:19:58:  14000000
# INFO  @ Wed, 24 Aug 2022 13:20:01:  15000000
# INFO  @ Wed, 24 Aug 2022 13:20:04:  16000000
# INFO  @ Wed, 24 Aug 2022 13:20:07:  17000000
# INFO  @ Wed, 24 Aug 2022 13:20:10:  18000000
# INFO  @ Wed, 24 Aug 2022 13:20:11: 18145111 reads have been read.
# INFO  @ Wed, 24 Aug 2022 13:20:11: #1 tag size is determined as 49 bps
# INFO  @ Wed, 24 Aug 2022 13:20:11: #1 tag size = 49.0
# INFO  @ Wed, 24 Aug 2022 13:20:11: #1  total tags in treatment: 18145111
# INFO  @ Wed, 24 Aug 2022 13:20:11: #1 finished!
# INFO  @ Wed, 24 Aug 2022 13:20:11: #2 Build Peak Model...
# INFO  @ Wed, 24 Aug 2022 13:20:11: #2 Skipped...
# INFO  @ Wed, 24 Aug 2022 13:20:11: #2 Use 150 as fragment length
# INFO  @ Wed, 24 Aug 2022 13:20:11: #2 Sequencing ends will be shifted towards 5' by 75 bp(s)
# INFO  @ Wed, 24 Aug 2022 13:20:11: #3 Call peaks...
# INFO  @ Wed, 24 Aug 2022 13:20:11: #3 Going to call summits inside each peak ...
# INFO  @ Wed, 24 Aug 2022 13:20:11: #3 Pre-compute pvalue-qvalue table...
# DEBUG @ Wed, 24 Aug 2022 13:20:11: Start to calculate pvalue stat...
# DEBUG @ Wed, 24 Aug 2022 13:20:44: access pq hash for 32888100 times
# INFO  @ Wed, 24 Aug 2022 13:20:44: #3 Call peaks for each chromosome...
# INFO  @ Wed, 24 Aug 2022 13:21:45: #4 Write output xls file... 04_peaks.xls
# INFO  @ Wed, 24 Aug 2022 13:21:45: #4 Write peak in narrowPeak format file... 04_peaks.narrowPeak
# INFO  @ Wed, 24 Aug 2022 13:21:46: #4 Write summits bed file... 04_summits.bed
# INFO  @ Wed, 24 Aug 2022 13:21:46: Done!
#
# python3 -m dictys  chromatin wellington --nth 4 tmp_static/Subset12/reads.bam tmp_static/Subset12/reads.bai tmp_static/Subset12/peaks.bed tmp_static/Subset12/footprints.bed
# [bam_sort_core] merging from 20 files and 4 in-memory blocks...
# INFO  @ Wed, 24 Aug 2022 13:19:58:
# # Command line: callpeak -t tmp_static/Subset5/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['tmp_static/Subset5/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Wed, 24 Aug 2022 13:19:58: #1 read tag files...
# INFO  @ Wed, 24 Aug 2022 13:19:58: #1 read treatment tags...
# DEBUG @ Wed, 24 Aug 2022 13:19:58: Testing format BAM
# INFO  @ Wed, 24 Aug 2022 13:19:58: Detected format is: BAM
# INFO  @ Wed, 24 Aug 2022 13:19:58: * Input file is gzipped.
# INFO  @ Wed, 24 Aug 2022 13:20:01:  1000000
# INFO  @ Wed, 24 Aug 2022 13:20:05:  2000000
# INFO  @ Wed, 24 Aug 2022 13:20:08:  3000000
# INFO  @ Wed, 24 Aug 2022 13:20:11:  4000000
# INFO  @ Wed, 24 Aug 2022 13:20:14:  5000000
# INFO  @ Wed, 24 Aug 2022 13:20:17:  6000000
# INFO  @ Wed, 24 Aug 2022 13:20:20:  7000000
# INFO  @ Wed, 24 Aug 2022 13:20:23:  8000000
# INFO  @ Wed, 24 Aug 2022 13:20:27:  9000000
# INFO  @ Wed, 24 Aug 2022 13:20:30:  10000000
# INFO  @ Wed, 24 Aug 2022 13:20:33:  11000000
# INFO  @ Wed, 24 Aug 2022 13:20:36:  12000000
# INFO  @ Wed, 24 Aug 2022 13:20:39:  13000000
# INFO  @ Wed, 24 Aug 2022 13:20:42:  14000000
# INFO  @ Wed, 24 Aug 2022 13:20:45:  15000000
# INFO  @ Wed, 24 Aug 2022 13:20:48:  16000000
# INFO  @ Wed, 24 Aug 2022 13:20:52:  17000000
# INFO  @ Wed, 24 Aug 2022 13:20:55:  18000000
# INFO  @ Wed, 24 Aug 2022 13:20:58:  19000000
# INFO  @ Wed, 24 Aug 2022 13:21:01:  20000000
# INFO  @ Wed, 24 Aug 2022 13:21:04:  21000000
# INFO  @ Wed, 24 Aug 2022 13:21:07:  22000000
# INFO  @ Wed, 24 Aug 2022 13:21:10:  23000000
# INFO  @ Wed, 24 Aug 2022 13:21:13:  24000000
# INFO  @ Wed, 24 Aug 2022 13:21:17:  25000000
# INFO  @ Wed, 24 Aug 2022 13:21:17: 25033750 reads have been read.
# INFO  @ Wed, 24 Aug 2022 13:21:17: #1 tag size is determined as 49 bps
# INFO  @ Wed, 24 Aug 2022 13:21:17: #1 tag size = 49.0
# INFO  @ Wed, 24 Aug 2022 13:21:17: #1  total tags in treatment: 25033750
# INFO  @ Wed, 24 Aug 2022 13:21:17: #1 finished!
# INFO  @ Wed, 24 Aug 2022 13:21:17: #2 Build Peak Model...
# INFO  @ Wed, 24 Aug 2022 13:21:17: #2 Skipped...
# INFO  @ Wed, 24 Aug 2022 13:21:17: #2 Use 150 as fragment length
# INFO  @ Wed, 24 Aug 2022 13:21:17: #2 Sequencing ends will be shifted towards 5' by 75 bp(s)
# INFO  @ Wed, 24 Aug 2022 13:21:17: #3 Call peaks...
# INFO  @ Wed, 24 Aug 2022 13:21:17: #3 Going to call summits inside each peak ...
# INFO  @ Wed, 24 Aug 2022 13:21:17: #3 Pre-compute pvalue-qvalue table...
# DEBUG @ Wed, 24 Aug 2022 13:21:17: Start to calculate pvalue stat...
# DEBUG @ Wed, 24 Aug 2022 13:22:18: access pq hash for 37142429 times
# INFO  @ Wed, 24 Aug 2022 13:22:19: #3 Call peaks for each chromosome...
# INFO  @ Wed, 24 Aug 2022 13:23:04: #4 Write output xls file... 04_peaks.xls
# INFO  @ Wed, 24 Aug 2022 13:23:05: #4 Write peak in narrowPeak format file... 04_peaks.narrowPeak
# INFO  @ Wed, 24 Aug 2022 13:23:05: #4 Write summits bed file... 04_summits.bed
# INFO  @ Wed, 24 Aug 2022 13:23:05: Done!
#
# python3 -m dictys  chromatin wellington --nth 4 tmp_static/Subset5/reads.bam tmp_static/Subset5/reads.bai tmp_static/Subset5/peaks.bed tmp_static/Subset5/footprints.bed
# [bam_sort_core] merging from 24 files and 4 in-memory blocks...
# INFO  @ Wed, 24 Aug 2022 13:19:57:
# # Command line: callpeak -t tmp_static/Subset10/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['tmp_static/Subset10/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Wed, 24 Aug 2022 13:19:57: #1 read tag files...
# INFO  @ Wed, 24 Aug 2022 13:19:57: #1 read treatment tags...
# DEBUG @ Wed, 24 Aug 2022 13:19:57: Testing format BAM
# INFO  @ Wed, 24 Aug 2022 13:19:57: Detected format is: BAM
# INFO  @ Wed, 24 Aug 2022 13:19:57: * Input file is gzipped.
# INFO  @ Wed, 24 Aug 2022 13:20:00:  1000000
# INFO  @ Wed, 24 Aug 2022 13:20:04:  2000000
# INFO  @ Wed, 24 Aug 2022 13:20:07:  3000000
# INFO  @ Wed, 24 Aug 2022 13:20:10:  4000000
# INFO  @ Wed, 24 Aug 2022 13:20:13:  5000000
# INFO  @ Wed, 24 Aug 2022 13:20:17:  6000000
# INFO  @ Wed, 24 Aug 2022 13:20:20:  7000000
# INFO  @ Wed, 24 Aug 2022 13:20:23:  8000000
# INFO  @ Wed, 24 Aug 2022 13:20:26:  9000000
# INFO  @ Wed, 24 Aug 2022 13:20:29:  10000000
# INFO  @ Wed, 24 Aug 2022 13:20:32:  11000000
# INFO  @ Wed, 24 Aug 2022 13:20:35:  12000000
# INFO  @ Wed, 24 Aug 2022 13:20:38:  13000000
# INFO  @ Wed, 24 Aug 2022 13:20:42:  14000000
# INFO  @ Wed, 24 Aug 2022 13:20:45:  15000000
# INFO  @ Wed, 24 Aug 2022 13:20:48:  16000000
# INFO  @ Wed, 24 Aug 2022 13:20:51:  17000000
# INFO  @ Wed, 24 Aug 2022 13:20:54:  18000000
# INFO  @ Wed, 24 Aug 2022 13:20:57:  19000000
# INFO  @ Wed, 24 Aug 2022 13:21:00:  20000000
# INFO  @ Wed, 24 Aug 2022 13:21:04:  21000000
# INFO  @ Wed, 24 Aug 2022 13:21:07:  22000000
# INFO  @ Wed, 24 Aug 2022 13:21:10:  23000000
# INFO  @ Wed, 24 Aug 2022 13:21:13:  24000000
# INFO  @ Wed, 24 Aug 2022 13:21:16:  25000000
# INFO  @ Wed, 24 Aug 2022 13:21:19: 25843096 reads have been read.
# INFO  @ Wed, 24 Aug 2022 13:21:19: #1 tag size is determined as 49 bps
# INFO  @ Wed, 24 Aug 2022 13:21:19: #1 tag size = 49.0
# INFO  @ Wed, 24 Aug 2022 13:21:19: #1  total tags in treatment: 25843096
# INFO  @ Wed, 24 Aug 2022 13:21:19: #1 finished!
# INFO  @ Wed, 24 Aug 2022 13:21:19: #2 Build Peak Model...
# INFO  @ Wed, 24 Aug 2022 13:21:19: #2 Skipped...
# INFO  @ Wed, 24 Aug 2022 13:21:19: #2 Use 150 as fragment length
# INFO  @ Wed, 24 Aug 2022 13:21:19: #2 Sequencing ends will be shifted towards 5' by 75 bp(s)
# INFO  @ Wed, 24 Aug 2022 13:21:19: #3 Call peaks...
# INFO  @ Wed, 24 Aug 2022 13:21:19: #3 Going to call summits inside each peak ...
# INFO  @ Wed, 24 Aug 2022 13:21:19: #3 Pre-compute pvalue-qvalue table...
# DEBUG @ Wed, 24 Aug 2022 13:21:19: Start to calculate pvalue stat...
# DEBUG @ Wed, 24 Aug 2022 13:22:14: access pq hash for 43694530 times
# INFO  @ Wed, 24 Aug 2022 13:22:14: #3 Call peaks for each chromosome...
# INFO  @ Wed, 24 Aug 2022 13:23:11: #4 Write output xls file... 04_peaks.xls
# INFO  @ Wed, 24 Aug 2022 13:23:12: #4 Write peak in narrowPeak format file... 04_peaks.narrowPeak
# INFO  @ Wed, 24 Aug 2022 13:23:12: #4 Write summits bed file... 04_summits.bed
# INFO  @ Wed, 24 Aug 2022 13:23:12: Done!
#
# python3 -m dictys  chromatin wellington --nth 4 tmp_static/Subset10/reads.bam tmp_static/Subset10/reads.bai tmp_static/Subset10/peaks.bed tmp_static/Subset10/footprints.bed
# [bam_sort_core] merging from 24 files and 4 in-memory blocks...
# INFO  @ Wed, 24 Aug 2022 13:20:16:
# # Command line: callpeak -t tmp_static/Subset6/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['tmp_static/Subset6/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Wed, 24 Aug 2022 13:20:16: #1 read tag files...
# INFO  @ Wed, 24 Aug 2022 13:20:16: #1 read treatment tags...
# DEBUG @ Wed, 24 Aug 2022 13:20:16: Testing format BAM
# INFO  @ Wed, 24 Aug 2022 13:20:16: Detected format is: BAM
# INFO  @ Wed, 24 Aug 2022 13:20:16: * Input file is gzipped.
# INFO  @ Wed, 24 Aug 2022 13:20:19:  1000000
# INFO  @ Wed, 24 Aug 2022 13:20:23:  2000000
# INFO  @ Wed, 24 Aug 2022 13:20:26:  3000000
# INFO  @ Wed, 24 Aug 2022 13:20:29:  4000000
# INFO  @ Wed, 24 Aug 2022 13:20:32:  5000000
# INFO  @ Wed, 24 Aug 2022 13:20:35:  6000000
# INFO  @ Wed, 24 Aug 2022 13:20:38:  7000000
# INFO  @ Wed, 24 Aug 2022 13:20:41:  8000000
# INFO  @ Wed, 24 Aug 2022 13:20:44:  9000000
# INFO  @ Wed, 24 Aug 2022 13:20:48:  10000000
# INFO  @ Wed, 24 Aug 2022 13:20:51:  11000000
# INFO  @ Wed, 24 Aug 2022 13:20:54:  12000000
# INFO  @ Wed, 24 Aug 2022 13:20:57:  13000000
# INFO  @ Wed, 24 Aug 2022 13:21:00:  14000000
# INFO  @ Wed, 24 Aug 2022 13:21:03:  15000000
# INFO  @ Wed, 24 Aug 2022 13:21:06:  16000000
# INFO  @ Wed, 24 Aug 2022 13:21:09:  17000000
# INFO  @ Wed, 24 Aug 2022 13:21:12:  18000000
# INFO  @ Wed, 24 Aug 2022 13:21:15:  19000000
# INFO  @ Wed, 24 Aug 2022 13:21:19:  20000000
# INFO  @ Wed, 24 Aug 2022 13:21:22:  21000000
# INFO  @ Wed, 24 Aug 2022 13:21:25:  22000000
# INFO  @ Wed, 24 Aug 2022 13:21:28:  23000000
# INFO  @ Wed, 24 Aug 2022 13:21:31:  24000000
# INFO  @ Wed, 24 Aug 2022 13:21:34:  25000000
# INFO  @ Wed, 24 Aug 2022 13:21:37:  26000000
# INFO  @ Wed, 24 Aug 2022 13:21:40:  27000000
# INFO  @ Wed, 24 Aug 2022 13:21:44:  28000000
# INFO  @ Wed, 24 Aug 2022 13:21:44: 28274891 reads have been read.
# INFO  @ Wed, 24 Aug 2022 13:21:45: #1 tag size is determined as 49 bps
# INFO  @ Wed, 24 Aug 2022 13:21:45: #1 tag size = 49.0
# INFO  @ Wed, 24 Aug 2022 13:21:45: #1  total tags in treatment: 28274891
# INFO  @ Wed, 24 Aug 2022 13:21:45: #1 finished!
# INFO  @ Wed, 24 Aug 2022 13:21:45: #2 Build Peak Model...
# INFO  @ Wed, 24 Aug 2022 13:21:45: #2 Skipped...
# INFO  @ Wed, 24 Aug 2022 13:21:45: #2 Use 150 as fragment length
# INFO  @ Wed, 24 Aug 2022 13:21:45: #2 Sequencing ends will be shifted towards 5' by 75 bp(s)
# INFO  @ Wed, 24 Aug 2022 13:21:45: #3 Call peaks...
# INFO  @ Wed, 24 Aug 2022 13:21:45: #3 Going to call summits inside each peak ...
# INFO  @ Wed, 24 Aug 2022 13:21:45: #3 Pre-compute pvalue-qvalue table...
# DEBUG @ Wed, 24 Aug 2022 13:21:45: Start to calculate pvalue stat...
# DEBUG @ Wed, 24 Aug 2022 13:22:55: access pq hash for 40706409 times
# INFO  @ Wed, 24 Aug 2022 13:22:55: #3 Call peaks for each chromosome...
# INFO  @ Wed, 24 Aug 2022 13:23:44: #4 Write output xls file... 04_peaks.xls
# INFO  @ Wed, 24 Aug 2022 13:23:44: #4 Write peak in narrowPeak format file... 04_peaks.narrowPeak
# INFO  @ Wed, 24 Aug 2022 13:23:44: #4 Write summits bed file... 04_summits.bed
# INFO  @ Wed, 24 Aug 2022 13:23:44: Done!
#
# python3 -m dictys  chromatin wellington --nth 4 tmp_static/Subset6/reads.bam tmp_static/Subset6/reads.bai tmp_static/Subset6/peaks.bed tmp_static/Subset6/footprints.bed
# [bam_sort_core] merging from 28 files and 4 in-memory blocks...
# INFO  @ Wed, 24 Aug 2022 13:20:39:
# # Command line: callpeak -t tmp_static/Subset7/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['tmp_static/Subset7/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# # Searching for subpeak summits is on
#
# INFO  @ Wed, 24 Aug 2022 13:20:39: #1 read tag files...
# INFO  @ Wed, 24 Aug 2022 13:20:39: #1 read treatment tags...
# DEBUG @ Wed, 24 Aug 2022 13:20:39: Testing format BAM
# INFO  @ Wed, 24 Aug 2022 13:20:39: Detected format is: BAM
# INFO  @ Wed, 24 Aug 2022 13:20:39: * Input file is gzipped.
# INFO  @ Wed, 24 Aug 2022 13:20:43:  1000000
# INFO  @ Wed, 24 Aug 2022 13:20:46:  2000000
# INFO  @ Wed, 24 Aug 2022 13:20:49:  3000000
# INFO  @ Wed, 24 Aug 2022 13:20:52:  4000000
# INFO  @ Wed, 24 Aug 2022 13:20:55:  5000000
# INFO  @ Wed, 24 Aug 2022 13:20:58:  6000000
# INFO  @ Wed, 24 Aug 2022 13:21:01:  7000000
# INFO  @ Wed, 24 Aug 2022 13:21:05:  8000000
# INFO  @ Wed, 24 Aug 2022 13:21:08:  9000000
# INFO  @ Wed, 24 Aug 2022 13:21:11:  10000000
# INFO  @ Wed, 24 Aug 2022 13:21:14:  11000000
# INFO  @ Wed, 24 Aug 2022 13:21:17:  12000000
# INFO  @ Wed, 24 Aug 2022 13:21:20:  13000000
# INFO  @ Wed, 24 Aug 2022 13:21:23:  14000000
# INFO  @ Wed, 24 Aug 2022 13:21:27:  15000000
# INFO  @ Wed, 24 Aug 2022 13:21:30:  16000000
# INFO  @ Wed, 24 Aug 2022 13:21:33:  17000000
# INFO  @ Wed, 24 Aug 2022 13:21:36:  18000000
# INFO  @ Wed, 24 Aug 2022 13:21:39:  19000000
# INFO  @ Wed, 24 Aug 2022 13:21:42:  20000000
# INFO  @ Wed, 24 Aug 2022 13:21:45:  21000000
# INFO  @ Wed, 24 Aug 2022 13:21:48:  22000000
# INFO  @ Wed, 24 Aug 2022 13:21:52:  23000000
# INFO  @ Wed, 24 Aug 2022 13:21:55:  24000000
# INFO  @ Wed, 24 Aug 2022 13:21:58:  25000000
# INFO  @ Wed, 24 Aug 2022 13:22:01:  26000000
# INFO  @ Wed, 24 Aug 2022 13:22:04:  27000000
# INFO  @ Wed, 24 Aug 2022 13:22:07:  28000000
# INFO  @ Wed, 24 Aug 2022 13:22:10:  29000000
# INFO  @ Wed, 24 Aug 2022 13:22:13:  30000000
# INFO  @ Wed, 24 Aug 2022 13:22:17:  31000000
# INFO  @ Wed, 24 Aug 2022 13:22:20:  32000000
# INFO  @ Wed, 24 Aug 2022 13:22:23:  33000000
# INFO  @ Wed, 24 Aug 2022 13:22:25: 33709717 reads have been read.
# INFO  @ Wed, 24 Aug 2022 13:22:26: #1 tag size is determined as 48 bps
# INFO  @ Wed, 24 Aug 2022 13:22:26: #1 tag size = 48.0
# INFO  @ Wed, 24 Aug 2022 13:22:26: #1  total tags in treatment: 33709717
# INFO  @ Wed, 24 Aug 2022 13:22:26: #1 finished!
# INFO  @ Wed, 24 Aug 2022 13:22:26: #2 Build Peak Model...
# INFO  @ Wed, 24 Aug 2022 13:22:26: #2 Skipped...
# INFO  @ Wed, 24 Aug 2022 13:22:26: #2 Use 150 as fragment length
# INFO  @ Wed, 24 Aug 2022 13:22:26: #2 Sequencing ends will be shifted towards 5' by 75 bp(s)
# INFO  @ Wed, 24 Aug 2022 13:22:26: #3 Call peaks...
# INFO  @ Wed, 24 Aug 2022 13:22:26: #3 Going to call summits inside each peak ...
# INFO  @ Wed, 24 Aug 2022 13:22:26: #3 Pre-compute pvalue-qvalue table...
# DEBUG @ Wed, 24 Aug 2022 13:22:26: Start to calculate pvalue stat...
# DEBUG @ Wed, 24 Aug 2022 13:23:49: access pq hash for 48797001 times
# INFO  @ Wed, 24 Aug 2022 13:23:49: #3 Call peaks for each chromosome...
# INFO  @ Wed, 24 Aug 2022 13:24:44: #4 Write output xls file... 04_peaks.xls
# INFO  @ Wed, 24 Aug 2022 13:24:45: #4 Write peak in narrowPeak format file... 04_peaks.narrowPeak
# INFO  @ Wed, 24 Aug 2022 13:24:45: #4 Write summits bed file... 04_summits.bed
# INFO  @ Wed, 24 Aug 2022 13:24:45: Done!
#
# python3 -m dictys  chromatin wellington --nth 4 tmp_static/Subset7/reads.bam tmp_static/Subset7/reads.bai tmp_static/Subset7/peaks.bed tmp_static/Subset7/footprints.bed
# [bam_sort_core] merging from 28 files and 4 in-memory blocks...
# INFO  @ Wed, 24 Aug 2022 13:20:43:
# # Command line: callpeak -t tmp_static/Subset4/reads.bam -n 04 -g hs --nomodel --shift -75 --extsize 150 --keep-dup all --verbose 4 --call-summits -q 0.05
# # ARGUMENTS LIST:
# # name = 04
# # format = AUTO
# # ChIP-seq file = ['tmp_static/Subset4/reads.bam']
# # control file = None
# # effective genome size = 2.70e+09
# # band width = 300
# # model fold = [5, 50]
# # qvalue cutoff = 5.00e-02
# # The maximum gap between significant sites is assigned as the read length/tag size.
# # The minimum length of peaks is assigned as the predicted fragment length "d".
# # Larger dataset will be scaled towards smaller dataset.
# # Range for calculating regional lambda is: 10000 bps
# # Broad region calling is off
# # Paired-End mode is off
# ...
# 		BED/Header formatted lines: 25001
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 25001
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 19 (avg size of targets)
# 	Background files for 19 bp fragments found.
# 	Custom genome sequence directory: data/genome
#
# 	Extracting sequences from file: data/genome/genome.fa
# 	Looking for peak sequences in a single file (data/genome/genome.fa)
# 	Extracting 2545 sequences from chr1
# 	Extracting 1069 sequences from chr10
# 	Extracting 1235 sequences from chr11
# 	Extracting 1319 sequences from chr12
# 	Extracting 498 sequences from chr13
# 	Extracting 786 sequences from chr14
# 	Extracting 793 sequences from chr15
# 	Extracting 1129 sequences from chr16
# 	Extracting 1657 sequences from chr17
# 	Extracting 375 sequences from chr18
# 	Extracting 1775 sequences from chr19
# 	Extracting 1659 sequences from chr2
# 	Extracting 667 sequences from chr20
# 	Extracting 327 sequences from chr21
# 	Extracting 623 sequences from chr22
# 	Extracting 1441 sequences from chr3
# 	Extracting 845 sequences from chr4
# 	Extracting 1107 sequences from chr5
# 	Extracting 1391 sequences from chr6
# 	Extracting 1192 sequences from chr7
# 	Extracting 932 sequences from chr8
# 	Extracting 1055 sequences from chr9
# 	Extracting 556 sequences from chrX
#
#
# 	Reading input files...
# 	24976 total sequences read
# 	769 motifs loaded
# 	Finding instances of 769 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = 14-reform-split/aaaab
# 	Genome = data/genome
# 	Output Directory = 15-motifscan/aaaab
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Will use repeat masked sequences
# 	Will find motif(s) in data/motifs.motif
# 	Using Custom Genome
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 25001
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 25001
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 19 (avg size of targets)
# 	Background files for 19 bp fragments found.
# 	Custom genome sequence directory: data/genome
#
# 	Extracting sequences from file: data/genome/genome.fa
# 	Looking for peak sequences in a single file (data/genome/genome.fa)
# 	Extracting 2593 sequences from chr1
# 	Extracting 1020 sequences from chr10
# 	Extracting 1332 sequences from chr11
# 	Extracting 1281 sequences from chr12
# 	Extracting 451 sequences from chr13
# 	Extracting 856 sequences from chr14
# 	Extracting 727 sequences from chr15
# 	Extracting 1143 sequences from chr16
# 	Extracting 1568 sequences from chr17
# 	Extracting 380 sequences from chr18
# 	Extracting 1916 sequences from chr19
# 	Extracting 1735 sequences from chr2
# 	Extracting 671 sequences from chr20
# 	Extracting 403 sequences from chr21
# 	Extracting 596 sequences from chr22
# 	Extracting 1358 sequences from chr3
# 	Extracting 839 sequences from chr4
# 	Extracting 1103 sequences from chr5
# 	Extracting 1381 sequences from chr6
# 	Extracting 1129 sequences from chr7
# 	Extracting 896 sequences from chr8
# 	Extracting 1070 sequences from chr9
# 	Extracting 505 sequences from chrX
# 	Extracting 1 sequences from chrY
#
#
# 	Reading input files...
# 	24954 total sequences read
# 	769 motifs loaded
# 	Finding instances of 769 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = 14-reform-split/aaaaa
# 	Genome = data/genome
# 	Output Directory = 15-motifscan/aaaaa
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Will use repeat masked sequences
# 	Will find motif(s) in data/motifs.motif
# 	Using Custom Genome
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 25001
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 25001
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 20 (avg size of targets)
# 	Background files for 20 bp fragments found.
# 	Custom genome sequence directory: data/genome
#
# 	Extracting sequences from file: data/genome/genome.fa
# 	Looking for peak sequences in a single file (data/genome/genome.fa)
# 	Extracting 2639 sequences from chr1
# 	Extracting 1003 sequences from chr10
# 	Extracting 1306 sequences from chr11
# 	Extracting 1243 sequences from chr12
# 	Extracting 390 sequences from chr13
# 	Extracting 802 sequences from chr14
# 	Extracting 683 sequences from chr15
# 	Extracting 1191 sequences from chr16
# 	Extracting 1809 sequences from chr17
# 	Extracting 327 sequences from chr18
# 	Extracting 2310 sequences from chr19
# 	Extracting 1564 sequences from chr2
# 	Extracting 657 sequences from chr20
# 	Extracting 573 sequences from chr21
# 	Extracting 620 sequences from chr22
# 	Extracting 1322 sequences from chr3
# 	Extracting 815 sequences from chr4
# 	Extracting 992 sequences from chr5
# 	Extracting 1245 sequences from chr6
# 	Extracting 1214 sequences from chr7
# 	Extracting 811 sequences from chr8
# 	Extracting 1034 sequences from chr9
# 	Extracting 392 sequences from chrX
# 	Extracting 1 sequences from chrY
#
#
# 	Reading input files...
# 	24943 total sequences read
# 	769 motifs loaded
# 	Finding instances of 769 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# python3 -m dictys  chromatin binding  tmp_static/Subset3/wellington.tsv.gz tmp_static/Subset3/homer.tsv.gz tmp_static/Subset3/binding.tsv.gz
# python3 -m dictys  chromatin tssdist  tmp_static/Subset3/expression.tsv.gz tmp_static/Subset3/wellington.tsv.gz data/gene.bed tmp_static/Subset3/tssdist.tsv.gz
# python3 -m dictys  chromatin linking  tmp_static/Subset3/binding.tsv.gz tmp_static/Subset3/tssdist.tsv.gz tmp_static/Subset3/linking.tsv.gz
# python3 -m dictys  chromatin binlinking  tmp_static/Subset3/linking.tsv.gz tmp_static/Subset3/binlinking.tsv.gz 20
# Reading BED File...
# Calculating footprints...
# Waiting for the last 30 jobs to finish...
#
# python3 -m dictys  chromatin homer --nth 4 tmp_static/Subset2/footprints.bed data/motifs.motif data/genome tmp_static/Subset2/expression.tsv.gz tmp_static/Subset2/motifs.bed tmp_static/Subset2/wellington.tsv.gz tmp_static/Subset2/homer.tsv.gz
#
# 	Position file = 14-reform-split/aaaad
# 	Genome = data/genome
# 	Output Directory = 15-motifscan/aaaad
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Will use repeat masked sequences
# 	Will find motif(s) in data/motifs.motif
# 	Using Custom Genome
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 24997
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 24997
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 19 (avg size of targets)
# 	Background files for 19 bp fragments found.
# 	Custom genome sequence directory: data/genome
#
# 	Extracting sequences from file: data/genome/genome.fa
# 	Looking for peak sequences in a single file (data/genome/genome.fa)
# 	Extracting 2573 sequences from chr1
# 	Extracting 1095 sequences from chr10
# 	Extracting 1369 sequences from chr11
# 	Extracting 1331 sequences from chr12
# 	Extracting 486 sequences from chr13
# 	Extracting 803 sequences from chr14
# 	Extracting 786 sequences from chr15
# 	Extracting 1075 sequences from chr16
# 	Extracting 1601 sequences from chr17
# 	Extracting 393 sequences from chr18
# 	Extracting 1750 sequences from chr19
# 	Extracting 1658 sequences from chr2
# 	Extracting 722 sequences from chr20
# 	Extracting 339 sequences from chr21
# 	Extracting 686 sequences from chr22
# 	Extracting 1410 sequences from chr3
# 	Extracting 833 sequences from chr4
# 	Extracting 1048 sequences from chr5
# 	Extracting 1416 sequences from chr6
# 	Extracting 1123 sequences from chr7
# 	Extracting 862 sequences from chr8
# 	Extracting 1059 sequences from chr9
# 	Extracting 534 sequences from chrX
# 	Extracting 1 sequences from chrY
#
#
# 	Reading input files...
# 	24953 total sequences read
# 	769 motifs loaded
# 	Finding instances of 769 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = 14-reform-split/aaaab
# 	Genome = data/genome
# 	Output Directory = 15-motifscan/aaaab
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Will use repeat masked sequences
# 	Will find motif(s) in data/motifs.motif
# 	Using Custom Genome
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 25001
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 25001
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 19 (avg size of targets)
# 	Background files for 19 bp fragments found.
# 	Custom genome sequence directory: data/genome
#
# 	Extracting sequences from file: data/genome/genome.fa
# 	Looking for peak sequences in a single file (data/genome/genome.fa)
# 	Extracting 2606 sequences from chr1
# 	Extracting 1006 sequences from chr10
# 	Extracting 1329 sequences from chr11
# 	Extracting 1250 sequences from chr12
# 	Extracting 422 sequences from chr13
# 	Extracting 809 sequences from chr14
# 	Extracting 771 sequences from chr15
# 	Extracting 1161 sequences from chr16
# 	Extracting 1722 sequences from chr17
# 	Extracting 376 sequences from chr18
# 	Extracting 1959 sequences from chr19
# 	Extracting 1608 sequences from chr2
# 	Extracting 675 sequences from chr20
# 	Extracting 437 sequences from chr21
# 	Extracting 631 sequences from chr22
# 	Extracting 1366 sequences from chr3
# 	Extracting 818 sequences from chr4
# 	Extracting 1050 sequences from chr5
# 	Extracting 1293 sequences from chr6
# 	Extracting 1174 sequences from chr7
# 	Extracting 872 sequences from chr8
# 	Extracting 1081 sequences from chr9
# 	Extracting 521 sequences from chrX
#
#
# 	Reading input files...
# 	24937 total sequences read
# 	769 motifs loaded
# 	Finding instances of 769 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = 14-reform-split/aaaac
# 	Genome = data/genome
# 	Output Directory = 15-motifscan/aaaac
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Will use repeat masked sequences
# 	Will find motif(s) in data/motifs.motif
# 	Using Custom Genome
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 25001
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 25001
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 19 (avg size of targets)
# 	Background files for 19 bp fragments found.
# 	Custom genome sequence directory: data/genome
#
# 	Extracting sequences from file: data/genome/genome.fa
# 	Looking for peak sequences in a single file (data/genome/genome.fa)
# 	Extracting 2503 sequences from chr1
# 	Extracting 1056 sequences from chr10
# 	Extracting 1346 sequences from chr11
# 	Extracting 1261 sequences from chr12
# 	Extracting 430 sequences from chr13
# 	Extracting 839 sequences from chr14
# 	Extracting 797 sequences from chr15
# 	Extracting 1123 sequences from chr16
# 	Extracting 1637 sequences from chr17
# 	Extracting 341 sequences from chr18
# 	Extracting 1800 sequences from chr19
# 	Extracting 1673 sequences from chr2
# 	Extracting 724 sequences from chr20
# 	Extracting 355 sequences from chr21
# 	Extracting 670 sequences from chr22
# 	Extracting 1432 sequences from chr3
# 	Extracting 817 sequences from chr4
# 	Extracting 1121 sequences from chr5
# 	Extracting 1353 sequences from chr6
# 	Extracting 1161 sequences from chr7
# 	Extracting 925 sequences from chr8
# 	Extracting 1056 sequences from chr9
# 	Extracting 550 sequences from chrX
# 	Extracting 1 sequences from chrY
#
#
# 	Reading input files...
# 	24971 total sequences read
# 	769 motifs loaded
# 	Finding instances of 769 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# 	Position file = 14-reform-split/aaaaa
# 	Genome = data/genome
# 	Output Directory = 15-motifscan/aaaaa
# 	Using actual sizes of regions (-size given)
# 	Fragment size set to given
# 	Will use repeat masked sequences
# 	Will find motif(s) in data/motifs.motif
# 	Using Custom Genome
# 	Peak/BED file conversion summary:
# 		BED/Header formatted lines: 25001
# 		peakfile formatted lines: 0
#
# 	Peak File Statistics:
# 		Total Peaks: 25001
# 		Redundant Peak IDs: 0
# 		Peaks lacking information: 0 (need at least 5 columns per peak)
# 		Peaks with misformatted coordinates: 0 (should be integer)
# 		Peaks with misformatted strand: 0 (should be either +/- or 0/1)
#
# 	Peak file looks good!
#
# 	Background fragment size set to 20 (avg size of targets)
# 	Background files for 20 bp fragments found.
# 	Custom genome sequence directory: data/genome
#
# 	Extracting sequences from file: data/genome/genome.fa
# 	Looking for peak sequences in a single file (data/genome/genome.fa)
# 	Extracting 2679 sequences from chr1
# 	Extracting 958 sequences from chr10
# 	Extracting 1280 sequences from chr11
# 	Extracting 1223 sequences from chr12
# 	Extracting 387 sequences from chr13
# 	Extracting 772 sequences from chr14
# 	Extracting 657 sequences from chr15
# 	Extracting 1229 sequences from chr16
# 	Extracting 1826 sequences from chr17
# 	Extracting 320 sequences from chr18
# 	Extracting 2415 sequences from chr19
# 	Extracting 1527 sequences from chr2
# 	Extracting 708 sequences from chr20
# 	Extracting 511 sequences from chr21
# 	Extracting 613 sequences from chr22
# 	Extracting 1333 sequences from chr3
# 	Extracting 811 sequences from chr4
# 	Extracting 971 sequences from chr5
# 	Extracting 1233 sequences from chr6
# 	Extracting 1195 sequences from chr7
# 	Extracting 827 sequences from chr8
# 	Extracting 1048 sequences from chr9
# 	Extracting 389 sequences from chrX
# 	Extracting 1 sequences from chrY
#
#
# 	Reading input files...
# 	24913 total sequences read
# 	769 motifs loaded
# 	Finding instances of 769 motif(s)
# 	|0%                                    50%                                  100%|
# 	=================================================================================
# 	Cleaning up tmp files...
#
#
# python3 -m dictys  chromatin binding  tmp_static/Subset2/wellington.tsv.gz tmp_static/Subset2/homer.tsv.gz tmp_static/Subset2/binding.tsv.gz
# python3 -m dictys  chromatin tssdist  tmp_static/Subset2/expression.tsv.gz tmp_static/Subset2/wellington.tsv.gz data/gene.bed tmp_static/Subset2/tssdist.tsv.gz
# python3 -m dictys  chromatin linking  tmp_static/Subset2/binding.tsv.gz tmp_static/Subset2/tssdist.tsv.gz tmp_static/Subset2/linking.tsv.gz
# python3 -m dictys  chromatin binlinking  tmp_static/Subset2/linking.tsv.gz tmp_static/Subset2/binlinking.tsv.gz 20
# make: Target `cpu' not remade because of errors.

# %% [markdown]
# ## 1.2 CPU part 1, command description
# ### preproc selects_rna
# This command subsets the RNA data separately for cells of each context/cell type.

# %%
# !python3 -m dictys preproc selects_rna -h
# Out:
# usage: dictys preproc selects_rna [-h] fi_reads fi_names fo_reads
#
# Select samples/cells based on external table for RNA data.
#
# positional arguments:
#   fi_reads    Path of input tsv file of full expression matrix
#   fi_names    Path of input text file of sample/cell names to select
#   fo_reads    Path of output tsv file of expression matrix of selected
#               samples/cells
#
# optional arguments:
#   -h, --help  show this help message and exit

# %% [markdown]
# ### preproc qc_reads
# This command removes low-read genes and cells for quality control.

# %%
# !python3 -m dictys preproc qc_reads -h
# Out:
# usage: dictys preproc qc_reads [-h]
#                                fi_reads fo_reads n_gene nc_gene ncp_gene
#                                n_cell nt_cell ntp_cell
#
# Quality control by bounding read counts. Quality control is perform separately
# on genes based on their cell statisics and on cells based on their gene
# statistics, iteratively until dataset remains unchanged. A gene or cell is
# removed if any of the QC criteria is violated at any time in the iteration.
# All QC parameters can be set to 0 to disable QC filtering for that criterion.
#
# positional arguments:
#   fi_reads    Path of input tsv file of read count matrix. Rows are genes and
#               columns are cells.
#   fo_reads    Path of output tsv file of read count matrix after QC
#   n_gene      Lower bound on total read counts for gene QC
#   nc_gene     Lower bound on number of expressed cells for gene QC
#   ncp_gene    Lower bound on proportion of expressed cells for gene QC
#   n_cell      Lower bound on total read counts for cell QC
#   nt_cell     Lower bound on number of expressed genes for cell QC
#   ntp_cell    Lower bound on proportion of expressed genes for cell QC
#
# optional arguments:
#   -h, --help  show this help message and exit

# %% [markdown]
# ### preproc selects_atac
# This command combines per-cell bam files to a single bam file for each cell subset.

# %%
# !python3 -m dictys preproc selects_atac -h
# Out:
# usage: dictys preproc selects_atac [-h] fi_exp fi_list fo_list
#
# Select chromatin accessibility samples/cells based on presence in expression
# matrix.
#
# positional arguments:
#   fi_exp      Path of input tsv file of expression matrix. Column must be
#               sample/cell name.
#   fi_list     Path of input text file of selected cell names, one per line
#   fo_list     Path of output text file of selected cell names, one per line
#
# optional arguments:
#   -h, --help  show this help message and exit

# %% [markdown]
# ### chromatin macs2
# This command finds chromatin accessibility peaks with macs2

# %%
# !python3 -m dictys chromatin macs2 -h
# Out:
# usage: dictys chromatin macs2 [-h] [--qcut QCUT] [--nth NTH] [--nmax NMAX]
#                               fi_names fi_bam fo_bam fo_bai fo_bed genome_size
#
# Peak calling using macs2. Needs bam files for each cell in a given folder.
#
# positional arguments:
#   fi_names     Path of input text file containing one sample/cell name per
#                line for macs2 peak calling
#   fi_bam       Path of input folder that contains each cell's bam file by name
#                in fi_names
#   fo_bam       Path of output bam file for select samples/cells
#   fo_bai       Path of output bai file for select samples/cells
#   fo_bed       Path of output bed file of peaks
#   genome_size  Genome size input of macs2. Use shortcuts hs or mm for human or
#                mouse.
#
# optional arguments:
#   -h, --help   show this help message and exit
#   --qcut QCUT  Qvalue cutoff for macs2 (default: 0.05)
#   --nth NTH    Number of threads (default: 1)
#   --nmax NMAX  Maximum number of peaks to retain, ordered by macs2 score. Use
#                0 for no limit. (default: 500000)

# %% [markdown]
# ### chromatin wellington
# This command finds transcription factor footprints with wellington/pyDNase

# %%
# !python3 -m dictys chromatin wellington -h
# Out:
# usage: dictys chromatin wellington [-h] [--fi_blacklist FI_BLACKLIST]
#                                    [--cut CUT] [--nth NTH] [--nmax NMAX]
#                                    fi_bam fi_bai fi_bed fo_bed
#
# TF footprinting with wellington.
#
# positional arguments:
#   fi_bam                Path of input bam file of all reads
#   fi_bai                Path of input bai file of all reads
#   fi_bed                Path of input bed file of peaks
#   fo_bed                Path of output bed file of footprints
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --fi_blacklist FI_BLACKLIST
#                         Path of input bed file of blacklisted genome regions
#                         to be removed (default: None)
#   --cut CUT             Cutoff for wellington score (default: 10)
#   --nth NTH             Number of threads (default: 1)
#   --nmax NMAX           Maximum number of footprints to retain, ordered by
#                         wellington score. Use 0 for no limit. (default:
#                         100000)

# %% [markdown]
# ### chromatin homer
# This command scans for motif occurrences within provided regions (here open chromatin peaks or footprints) with homer.

# %%
# !python3 -m dictys chromatin homer -h
# Out:
# usage: dictys chromatin homer [-h] [--nth NTH]
#                               fi_bed fi_motif dirio_genome fi_exp fo_bed
#                               fo_wellington fo_homer
#
# Motif scan with homer.
#
# positional arguments:
#   fi_bed         Path of input bed file of regions
#   fi_motif       Path of input motif PWM file in homer format. Motifs must be
#                  named in format 'gene...' where gene matches gene names in
#                  fi_exp. Should not contain duplicates.
#   dirio_genome   Path of input & output folder or file for reference genome
#                  for homer. A separate hard copy is recommended because homer
#                  may write into the folder to preparse genome.
#   fi_exp         Path of input expression matrix file in tsv format. Used for
#                  mapping motifs to genes.
#   fo_bed         Path of output bed file of detected motifs
#   fo_wellington  Path of output tsv file of wellington scores in shape
#                  (region,motif)
#   fo_homer       Path of output tsv file of homer scores in shape
#                  (region,motif)
#
# optional arguments:
#   -h, --help     show this help message and exit
#   --nth NTH      Number of threads (default: 1)

# %% [markdown]
# ### chromatin binding
# This command computes an integrative score for TF binding based on scores from footprint/peak discovery and from homer.

# %%
# !python3 -m dictys chromatin binding -h
# Out:
# usage: dictys chromatin binding [-h] [--cuth CUTH] [--cutw CUTW] [--cut CUT]
#                                 [--combine COMBINE] [--mode MODE]
#                                 fi_wellington fi_homer fo_bind
#
# Finding TF binding events. Combines wellington and homer outputs to infer TF
# binding events by merging motifs to TFs.
#
# positional arguments:
#   fi_wellington      Path of input tsv file of wellington output
#   fi_homer           Path of input tsv file of homer output
#   fo_bind            Path of output tsv file of binding events
#
# optional arguments:
#   -h, --help         show this help message and exit
#   --cuth CUTH        Homer score cutoff (default: 0)
#   --cutw CUTW        Wellington score cutoff (default: 0)
#   --cut CUT          Final score (integrating homer & wellington) cutoff
#                      (default: None)
#   --combine COMBINE  Method to combine scores of motifs of the same TF.
#                      Accepts: max, mean, sum. (default: max)
#   --mode MODE        Mode to compute final score. Accepts binary flags: 1: Add
#                      log(wellington score) 2: Add log(homer score) 4: Subtract
#                      log(10)*(distance_to_tss)/1E6 (default: 3)

# %% [markdown]
# ### chromatin tssdist
# This command computes the distance between each (open chromatin) region and each gene's transcription start site to prioritize nearby pairs that are more likely to have regulatory effects.

# %%
# !python3 -m dictys chromatin tssdist -h
# Out:
# usage: dictys chromatin tssdist [-h] [--cut CUT] [--nmin NMIN] [--nmax NMAX]
#                                 fi_exp fi_wellington fi_tss fo_dist
#
# Annotating TF bond regions to target genes based on distance to TSS.
#
# positional arguments:
#   fi_exp         Path of input expression matrix file in tsv format to obtain
#                  gene names
#   fi_wellington  Path of input tsv file of wellington scores to obtain DNA
#                  regions
#   fi_tss         Path of input bed file for gene region and strand
#   fo_dist        Path of output tsv file of distance from TF-bond regions to
#                  TSS
#
# optional arguments:
#   -h, --help     show this help message and exit
#   --cut CUT      Distance cutoff between DNA region and target gene TSS
#                  (default: 500000)
#   --nmin NMIN    Minimal total number of links to recover (default: 1)
#   --nmax NMAX    Maximal total number of links to recover (default: 10000000)

# %% [markdown]
# ### chromatin linking
# This command links TFs to its potential target genes via the relation: TF --- motif --- region --- gene.

# %%
# !python3 -m dictys chromatin linking -h
# Out:
# usage: dictys chromatin linking [-h] [--combine COMBINE] [--mode MODE]
#                                 fi_binding fi_dist fo_linking
#
# Linking regulators and targets with scores.
#
# positional arguments:
#   fi_binding         Path of input tsv file of binding events
#   fi_dist            Path of input tsv file of distance from TF-bond regions
#                      to TSS
#   fo_linking         Path of output matrix file of TF to potential target gene
#                      link scores
#
# optional arguments:
#   -h, --help         show this help message and exit
#   --combine COMBINE  Method to combine scores of motifs of the same TF.
#                      Accepts: max, mean, sum. (default: max)
#   --mode MODE        Mode to compute final score. Accepts binary flags: 4:
#                      Subtract log(10)*(distance_to_tss)/1E6 (default: 4)

# %% [markdown]
# ### chromatin binlinking
# This command selects the strongest TF-target gene pairs as a TF binding network that constrains the GRN to be inferred.

# %%
# !python3 -m dictys chromatin binlinking -h
# Out:
# usage: dictys chromatin binlinking [-h] [--axis AXIS] [--selfreg SELFREG]
#                                    [--inf INF]
#                                    fi_linking fo_binlinking n
#
# Converting regulator-target link score matrix to binary. Chooses the top
# regulator-target links, separately for each target gene by default.
#
# positional arguments:
#   fi_linking         Path of input matrix file of TF to potential target gene
#                      link scores
#   fo_binlinking      Path of output matrix file of TF to potential target gene
#                      links
#   n                  Number of regulator-target links. n strongest links (with
#                      highest scores) are selected along axis axis. If greater
#                      than the maximum links available, all links will be
#                      selected subject to inf parameter constraint. Value -1
#                      selects all non-inf links.
#
# optional arguments:
#   -h, --help         show this help message and exit
#   --axis AXIS        Axis to choose the top links. If None, n links in total
#                      are selected among all regulator-target links. Defaults
#                      to 1, indicating n strongest links/regulators are
#                      selected for each target. (default: 1)
#   --selfreg SELFREG  How to handle self regulation. Accepts: error: Raise
#                      ValueError if seen in fi_linking (default: error)
#   --inf INF          Whether to select links with -inf score. Accepts: never.
#                      (default: never)

# %% [markdown]
# ## 2.1 GPU part, execution
# **This part should be skipped if you use CPU for pytorch.**
#
# This part performs GRN inference with scRNA-seq read counts on GPU.

# %%
# %%bash
# set -eo pipefail
# cd ..
# make -f makefiles/static.mk -j 2 -k gpu || true
# Out:
# python3 -m dictys  network reconstruct --device cuda:0 --nth 4 tmp_static/Subset1/expression.tsv.gz tmp_static/Subset1/binlinking.tsv.gz tmp_static/Subset1/net_weight.tsv.gz tmp_static/Subset1/net_meanvar.tsv.gz tmp_static/Subset1/net_covfactor.tsv.gz tmp_static/Subset1/net_loss.tsv.gz tmp_static/Subset1/net_stats.tsv.gz
# python3 -m dictys  network reconstruct --device cuda:0 --nth 4 tmp_static/Subset10/expression.tsv.gz tmp_static/Subset10/binlinking.tsv.gz tmp_static/Subset10/net_weight.tsv.gz tmp_static/Subset10/net_meanvar.tsv.gz tmp_static/Subset10/net_covfactor.tsv.gz tmp_static/Subset10/net_loss.tsv.gz tmp_static/Subset10/net_stats.tsv.gz
# python3 -m dictys  network reconstruct --device cuda:0 --nth 4 tmp_static/Subset11/expression.tsv.gz tmp_static/Subset11/binlinking.tsv.gz tmp_static/Subset11/net_weight.tsv.gz tmp_static/Subset11/net_meanvar.tsv.gz tmp_static/Subset11/net_covfactor.tsv.gz tmp_static/Subset11/net_loss.tsv.gz tmp_static/Subset11/net_stats.tsv.gz
# python3 -m dictys  network reconstruct --device cuda:0 --nth 4 tmp_static/Subset12/expression.tsv.gz tmp_static/Subset12/binlinking.tsv.gz tmp_static/Subset12/net_weight.tsv.gz tmp_static/Subset12/net_meanvar.tsv.gz tmp_static/Subset12/net_covfactor.tsv.gz tmp_static/Subset12/net_loss.tsv.gz tmp_static/Subset12/net_stats.tsv.gz
# python3 -m dictys  network reconstruct --device cuda:0 --nth 4 tmp_static/Subset13/expression.tsv.gz tmp_static/Subset13/binlinking.tsv.gz tmp_static/Subset13/net_weight.tsv.gz tmp_static/Subset13/net_meanvar.tsv.gz tmp_static/Subset13/net_covfactor.tsv.gz tmp_static/Subset13/net_loss.tsv.gz tmp_static/Subset13/net_stats.tsv.gz
# python3 -m dictys  network reconstruct --device cuda:0 --nth 4 tmp_static/Subset14/expression.tsv.gz tmp_static/Subset14/binlinking.tsv.gz tmp_static/Subset14/net_weight.tsv.gz tmp_static/Subset14/net_meanvar.tsv.gz tmp_static/Subset14/net_covfactor.tsv.gz tmp_static/Subset14/net_loss.tsv.gz tmp_static/Subset14/net_stats.tsv.gz
# python3 -m dictys  network reconstruct --device cuda:0 --nth 4 tmp_static/Subset2/expression.tsv.gz tmp_static/Subset2/binlinking.tsv.gz tmp_static/Subset2/net_weight.tsv.gz tmp_static/Subset2/net_meanvar.tsv.gz tmp_static/Subset2/net_covfactor.tsv.gz tmp_static/Subset2/net_loss.tsv.gz tmp_static/Subset2/net_stats.tsv.gz
# python3 -m dictys  network reconstruct --device cuda:0 --nth 4 tmp_static/Subset3/expression.tsv.gz tmp_static/Subset3/binlinking.tsv.gz tmp_static/Subset3/net_weight.tsv.gz tmp_static/Subset3/net_meanvar.tsv.gz tmp_static/Subset3/net_covfactor.tsv.gz tmp_static/Subset3/net_loss.tsv.gz tmp_static/Subset3/net_stats.tsv.gz
# python3 -m dictys  network reconstruct --device cuda:0 --nth 4 tmp_static/Subset4/expression.tsv.gz tmp_static/Subset4/binlinking.tsv.gz tmp_static/Subset4/net_weight.tsv.gz tmp_static/Subset4/net_meanvar.tsv.gz tmp_static/Subset4/net_covfactor.tsv.gz tmp_static/Subset4/net_loss.tsv.gz tmp_static/Subset4/net_stats.tsv.gz
# python3 -m dictys  network reconstruct --device cuda:0 --nth 4 tmp_static/Subset5/expression.tsv.gz tmp_static/Subset5/binlinking.tsv.gz tmp_static/Subset5/net_weight.tsv.gz tmp_static/Subset5/net_meanvar.tsv.gz tmp_static/Subset5/net_covfactor.tsv.gz tmp_static/Subset5/net_loss.tsv.gz tmp_static/Subset5/net_stats.tsv.gz
# python3 -m dictys  network reconstruct --device cuda:0 --nth 4 tmp_static/Subset6/expression.tsv.gz tmp_static/Subset6/binlinking.tsv.gz tmp_static/Subset6/net_weight.tsv.gz tmp_static/Subset6/net_meanvar.tsv.gz tmp_static/Subset6/net_covfactor.tsv.gz tmp_static/Subset6/net_loss.tsv.gz tmp_static/Subset6/net_stats.tsv.gz
# python3 -m dictys  network reconstruct --device cuda:0 --nth 4 tmp_static/Subset7/expression.tsv.gz tmp_static/Subset7/binlinking.tsv.gz tmp_static/Subset7/net_weight.tsv.gz tmp_static/Subset7/net_meanvar.tsv.gz tmp_static/Subset7/net_covfactor.tsv.gz tmp_static/Subset7/net_loss.tsv.gz tmp_static/Subset7/net_stats.tsv.gz
# python3 -m dictys  network reconstruct --device cuda:0 --nth 4 tmp_static/Subset8/expression.tsv.gz tmp_static/Subset8/binlinking.tsv.gz tmp_static/Subset8/net_weight.tsv.gz tmp_static/Subset8/net_meanvar.tsv.gz tmp_static/Subset8/net_covfactor.tsv.gz tmp_static/Subset8/net_loss.tsv.gz tmp_static/Subset8/net_stats.tsv.gz
# python3 -m dictys  network reconstruct --device cuda:0 --nth 4 tmp_static/Subset9/expression.tsv.gz tmp_static/Subset9/binlinking.tsv.gz tmp_static/Subset9/net_weight.tsv.gz tmp_static/Subset9/net_meanvar.tsv.gz tmp_static/Subset9/net_covfactor.tsv.gz tmp_static/Subset9/net_loss.tsv.gz tmp_static/Subset9/net_stats.tsv.gz

# %% [markdown]
# ## 2.2 GPU part, command description
# ### network reconstruct
# This command uses pyro and pytorch to infer the GRN with stochastic process model under the TF binding network constraint.

# %%
# !python3 -m dictys network reconstruct -h
# Out:
# usage: dictys network reconstruct [-h] [--lr LR] [--lrd LRD] [--nstep NSTEP]
#                                   [--npc NPC] [--fi_cov FI_COV]
#                                   [--model MODEL]
#                                   [--nstep_report NSTEP_REPORT]
#                                   [--rseed RSEED] [--device DEVICE]
#                                   [--dtype DTYPE] [--loss LOSS] [--nth NTH]
#                                   [--varmean VARMEAN] [--varstd VARSTD]
#                                   [--fo_weightz FO_WEIGHTZ]
#                                   [--scale_lyapunov SCALE_LYAPUNOV]
#                                   fi_exp fi_mask fo_weight fo_meanvar
#                                   fo_covfactor fo_loss fo_stats
#
# Reconstruct network with any pyro model in net_pyro_models that is based on
# covariance_model and has binary masks.
#
# positional arguments:
#   fi_exp                Path of input tsv file of expression matrix.
#   fi_mask               Path of input tsv file of mask matrix indicating which
#                         edges are allowed. Can be output of dictys chromatin
#                         binlinking.
#   fo_weight             Path of output tsv file of edge weight matrix
#   fo_meanvar            Path of output tsv file of mean and variance of each
#                         gene's relative log expression
#   fo_covfactor          Path of output tsv file of factors for the off-
#                         diagonal component of gene covariance matrix
#   fo_loss               Path of output tsv file of sublosses in each training
#                         step
#   fo_stats              Path of output tsv file of basic stats of each
#                         variable during training
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --lr LR               Initial iearning rate (default: 0.01)
#   --lrd LRD             Learning rate decay (default: 0.999)
#   --nstep NSTEP         Number of training steps (default: 4000)
#   --npc NPC             Number of unknown factors for covariance in
#                         multivariate distribution (default: 0)
#   --fi_cov FI_COV       Path of input tsv file of covariate matrix for each
#                         cell to be included. Should have covariate x cell
#                         shape. (default: None)
#   --model MODEL         Name of model to train (default: ou)
#   --nstep_report NSTEP_REPORT
#                         Number of steps to save each parameter distribution
#                         (default: 100)
#   --rseed RSEED         Initial random seed (default: 12345)
#   --device DEVICE       Device for pytorch and pyro. See TBA.... (default:
#                         cpu)
#   --dtype DTYPE         Data type for pytorch. See TBA... (default: float)
#   --loss LOSS           Loss function name (default: Trace_ELBO_site)
#   --nth NTH             Number of threads for CPU usage. When <1, use
#                         nth*(detected core count). (default: 1)
#   --varmean VARMEAN     Pyro parameter name for mean of effect size (default:
#                         N_0val)
#   --varstd VARSTD       Pyro parameter name for std of effect size to compute
#                         z scores. Use None if unavailable. (default: None)
#   --fo_weightz FO_WEIGHTZ
#                         Path of output tsv file of z score matrix of edge
#                         weights (default: None)
#   --scale_lyapunov SCALE_LYAPUNOV
#                         Scale of Lyapunov equation inequality loss (default:
#                         100000.0)

# %% [markdown]
# ## 3.1 CPU part 2, execution
# **This part should be skipped if you use CPU for pytorch.**
#
# This part performs network postprocessing to address variance estimation bias and indirect effects.

# %%
# %%bash
# set -eo pipefail
# cd ..
# make -f makefiles/static.mk -j 32 -k cpu || true
# Out:
# python3 -m dictys  network normalize --nth 4 tmp_static/Subset1/net_weight.tsv.gz tmp_static/Subset1/net_meanvar.tsv.gz tmp_static/Subset1/net_covfactor.tsv.gz tmp_static/Subset1/net_nweight.tsv.gz
# python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset1/net_meanvar.tsv.gz tmp_static/Subset1/net_weight.tsv.gz tmp_static/Subset1/net_covfactor.tsv.gz tmp_static/Subset1/net_iweight.tsv.gz
# python3 -m dictys  network normalize --nth 4 tmp_static/Subset10/net_weight.tsv.gz tmp_static/Subset10/net_meanvar.tsv.gz tmp_static/Subset10/net_covfactor.tsv.gz tmp_static/Subset10/net_nweight.tsv.gz
# python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset10/net_meanvar.tsv.gz tmp_static/Subset10/net_weight.tsv.gz tmp_static/Subset10/net_covfactor.tsv.gz tmp_static/Subset10/net_iweight.tsv.gz
# python3 -m dictys  network normalize --nth 4 tmp_static/Subset11/net_weight.tsv.gz tmp_static/Subset11/net_meanvar.tsv.gz tmp_static/Subset11/net_covfactor.tsv.gz tmp_static/Subset11/net_nweight.tsv.gz
# python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset11/net_meanvar.tsv.gz tmp_static/Subset11/net_weight.tsv.gz tmp_static/Subset11/net_covfactor.tsv.gz tmp_static/Subset11/net_iweight.tsv.gz
# python3 -m dictys  network normalize --nth 4 tmp_static/Subset12/net_weight.tsv.gz tmp_static/Subset12/net_meanvar.tsv.gz tmp_static/Subset12/net_covfactor.tsv.gz tmp_static/Subset12/net_nweight.tsv.gz
# python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset12/net_meanvar.tsv.gz tmp_static/Subset12/net_weight.tsv.gz tmp_static/Subset12/net_covfactor.tsv.gz tmp_static/Subset12/net_iweight.tsv.gz
# python3 -m dictys  network normalize --nth 4 tmp_static/Subset13/net_weight.tsv.gz tmp_static/Subset13/net_meanvar.tsv.gz tmp_static/Subset13/net_covfactor.tsv.gz tmp_static/Subset13/net_nweight.tsv.gz
# python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset13/net_meanvar.tsv.gz tmp_static/Subset13/net_weight.tsv.gz tmp_static/Subset13/net_covfactor.tsv.gz tmp_static/Subset13/net_iweight.tsv.gz
# python3 -m dictys  network normalize --nth 4 tmp_static/Subset14/net_weight.tsv.gz tmp_static/Subset14/net_meanvar.tsv.gz tmp_static/Subset14/net_covfactor.tsv.gz tmp_static/Subset14/net_nweight.tsv.gz
# python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset14/net_meanvar.tsv.gz tmp_static/Subset14/net_weight.tsv.gz tmp_static/Subset14/net_covfactor.tsv.gz tmp_static/Subset14/net_iweight.tsv.gz
# python3 -m dictys  network normalize --nth 4 tmp_static/Subset2/net_weight.tsv.gz tmp_static/Subset2/net_meanvar.tsv.gz tmp_static/Subset2/net_covfactor.tsv.gz tmp_static/Subset2/net_nweight.tsv.gz
# python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset2/net_meanvar.tsv.gz tmp_static/Subset2/net_weight.tsv.gz tmp_static/Subset2/net_covfactor.tsv.gz tmp_static/Subset2/net_iweight.tsv.gz
# python3 -m dictys  network normalize --nth 4 tmp_static/Subset3/net_weight.tsv.gz tmp_static/Subset3/net_meanvar.tsv.gz tmp_static/Subset3/net_covfactor.tsv.gz tmp_static/Subset3/net_nweight.tsv.gz
# python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset3/net_meanvar.tsv.gz tmp_static/Subset3/net_weight.tsv.gz tmp_static/Subset3/net_covfactor.tsv.gz tmp_static/Subset3/net_iweight.tsv.gz
# python3 -m dictys  network normalize --nth 4 tmp_static/Subset4/net_weight.tsv.gz tmp_static/Subset4/net_meanvar.tsv.gz tmp_static/Subset4/net_covfactor.tsv.gz tmp_static/Subset4/net_nweight.tsv.gz
# python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset4/net_meanvar.tsv.gz tmp_static/Subset4/net_weight.tsv.gz tmp_static/Subset4/net_covfactor.tsv.gz tmp_static/Subset4/net_iweight.tsv.gz
# python3 -m dictys  network normalize --nth 4 tmp_static/Subset5/net_weight.tsv.gz tmp_static/Subset5/net_meanvar.tsv.gz tmp_static/Subset5/net_covfactor.tsv.gz tmp_static/Subset5/net_nweight.tsv.gz
# python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset5/net_meanvar.tsv.gz tmp_static/Subset5/net_weight.tsv.gz tmp_static/Subset5/net_covfactor.tsv.gz tmp_static/Subset5/net_iweight.tsv.gz
# python3 -m dictys  network normalize --nth 4 tmp_static/Subset6/net_weight.tsv.gz tmp_static/Subset6/net_meanvar.tsv.gz tmp_static/Subset6/net_covfactor.tsv.gz tmp_static/Subset6/net_nweight.tsv.gz
# python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset6/net_meanvar.tsv.gz tmp_static/Subset6/net_weight.tsv.gz tmp_static/Subset6/net_covfactor.tsv.gz tmp_static/Subset6/net_iweight.tsv.gz
# python3 -m dictys  network normalize --nth 4 tmp_static/Subset7/net_weight.tsv.gz tmp_static/Subset7/net_meanvar.tsv.gz tmp_static/Subset7/net_covfactor.tsv.gz tmp_static/Subset7/net_nweight.tsv.gz
# python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset7/net_meanvar.tsv.gz tmp_static/Subset7/net_weight.tsv.gz tmp_static/Subset7/net_covfactor.tsv.gz tmp_static/Subset7/net_iweight.tsv.gz
# python3 -m dictys  network normalize --nth 4 tmp_static/Subset8/net_weight.tsv.gz tmp_static/Subset8/net_meanvar.tsv.gz tmp_static/Subset8/net_covfactor.tsv.gz tmp_static/Subset8/net_nweight.tsv.gz
# python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset8/net_meanvar.tsv.gz tmp_static/Subset8/net_weight.tsv.gz tmp_static/Subset8/net_covfactor.tsv.gz tmp_static/Subset8/net_iweight.tsv.gz
# python3 -m dictys  network normalize --nth 4 tmp_static/Subset9/net_weight.tsv.gz tmp_static/Subset9/net_meanvar.tsv.gz tmp_static/Subset9/net_covfactor.tsv.gz tmp_static/Subset9/net_nweight.tsv.gz
# python3 -m dictys  network indirect --nth 4 --fi_meanvar tmp_static/Subset9/net_meanvar.tsv.gz tmp_static/Subset9/net_weight.tsv.gz tmp_static/Subset9/net_covfactor.tsv.gz tmp_static/Subset9/net_iweight.tsv.gz
# python3 -m dictys  network normalize --nth 4 tmp_static/Subset13/net_iweight.tsv.gz tmp_static/Subset13/net_meanvar.tsv.gz tmp_static/Subset13/net_covfactor.tsv.gz tmp_static/Subset13/net_inweight.tsv.gz
# python3 -m dictys  network normalize --nth 4 tmp_static/Subset14/net_iweight.tsv.gz tmp_static/Subset14/net_meanvar.tsv.gz tmp_static/Subset14/net_covfactor.tsv.gz tmp_static/Subset14/net_inweight.tsv.gz
# python3 -m dictys  network normalize --nth 4 tmp_static/Subset11/net_iweight.tsv.gz tmp_static/Subset11/net_meanvar.tsv.gz tmp_static/Subset11/net_covfactor.tsv.gz tmp_static/Subset11/net_inweight.tsv.gz
# python3 -m dictys  network normalize --nth 4 tmp_static/Subset5/net_iweight.tsv.gz tmp_static/Subset5/net_meanvar.tsv.gz tmp_static/Subset5/net_covfactor.tsv.gz tmp_static/Subset5/net_inweight.tsv.gz
# python3 -m dictys  network normalize --nth 4 tmp_static/Subset12/net_iweight.tsv.gz tmp_static/Subset12/net_meanvar.tsv.gz tmp_static/Subset12/net_covfactor.tsv.gz tmp_static/Subset12/net_inweight.tsv.gz
# python3 -m dictys  network normalize --nth 4 tmp_static/Subset4/net_iweight.tsv.gz tmp_static/Subset4/net_meanvar.tsv.gz tmp_static/Subset4/net_covfactor.tsv.gz tmp_static/Subset4/net_inweight.tsv.gz
# python3 -m dictys  network normalize --nth 4 tmp_static/Subset8/net_iweight.tsv.gz tmp_static/Subset8/net_meanvar.tsv.gz tmp_static/Subset8/net_covfactor.tsv.gz tmp_static/Subset8/net_inweight.tsv.gz
# python3 -m dictys  network normalize --nth 4 tmp_static/Subset6/net_iweight.tsv.gz tmp_static/Subset6/net_meanvar.tsv.gz tmp_static/Subset6/net_covfactor.tsv.gz tmp_static/Subset6/net_inweight.tsv.gz
# python3 -m dictys  network normalize --nth 4 tmp_static/Subset9/net_iweight.tsv.gz tmp_static/Subset9/net_meanvar.tsv.gz tmp_static/Subset9/net_covfactor.tsv.gz tmp_static/Subset9/net_inweight.tsv.gz
# python3 -m dictys  network normalize --nth 4 tmp_static/Subset3/net_iweight.tsv.gz tmp_static/Subset3/net_meanvar.tsv.gz tmp_static/Subset3/net_covfactor.tsv.gz tmp_static/Subset3/net_inweight.tsv.gz
# python3 -m dictys  network normalize --nth 4 tmp_static/Subset2/net_iweight.tsv.gz tmp_static/Subset2/net_meanvar.tsv.gz tmp_static/Subset2/net_covfactor.tsv.gz tmp_static/Subset2/net_inweight.tsv.gz
# python3 -m dictys  network normalize --nth 4 tmp_static/Subset1/net_iweight.tsv.gz tmp_static/Subset1/net_meanvar.tsv.gz tmp_static/Subset1/net_covfactor.tsv.gz tmp_static/Subset1/net_inweight.tsv.gz
# python3 -m dictys  network normalize --nth 4 tmp_static/Subset10/net_iweight.tsv.gz tmp_static/Subset10/net_meanvar.tsv.gz tmp_static/Subset10/net_covfactor.tsv.gz tmp_static/Subset10/net_inweight.tsv.gz
# python3 -m dictys  network normalize --nth 4 tmp_static/Subset7/net_iweight.tsv.gz tmp_static/Subset7/net_meanvar.tsv.gz tmp_static/Subset7/net_covfactor.tsv.gz tmp_static/Subset7/net_inweight.tsv.gz

# %% [markdown]
# ## 3.2 CPU part 2, command description
# ### network normalize
# This command normalizes network edges based on the standard deviation of regulator and target genes. This can overcome biases in the estimation of variance of gene expression due to single-cell sparsity.

# %%
# !python3 -m dictys network normalize -h
# Out:
# usage: dictys network normalize [-h] [--norm NORM] [--nth NTH]
#                                 fi_weight fi_meanvar fi_covfactor fo_nweight
#
# Normalize edge strength. So they are more resistant to estimation bias of true
# expression level variance.
#
# positional arguments:
#   fi_weight     Path of input tsv file of edge weight matrix
#   fi_meanvar    Path of iput tsv file of mean and variance of each gene's
#                 relative log expression
#   fi_covfactor  Path of iput tsv file of factors for the off-diagonal
#                 component of gene covariance matrix
#   fo_nweight    Path of output tsv file of normalized edge weight matrix
#
# optional arguments:
#   -h, --help    show this help message and exit
#   --norm NORM   Type of normalization as binary flag values. Accepts: 1:
#                 Multiplying edge weight with stochastic noise std of TF 2:
#                 Dividing edge weight with stochastic noise std of target
#                 (default: 3)
#   --nth NTH     Number of threads for CPU usage. When <1, use nth*(detected
#                 core count). (default: 1)

# %% [markdown]
# ### network indirect
# This command computes the steady-state total effect (direct + indirect effects) networks from the kinetic direct effect network. The total effect network is **not yet integrated into network analysis functions**.

# %%
# !python3 -m dictys network indirect -h
# Out:
# usage: dictys network indirect [-h] [--norm NORM] [--fi_meanvar FI_MEANVAR]
#                                [--eigmin EIGMIN] [--eigmax EIGMAX]
#                                [--multiplier MULTIPLIER] [--nth NTH]
#                                fi_weight fi_covfactor fo_iweight
#
# Computes steady-state indirect effect of gene perturbation from OU process.
# Performs extra regularization on network by bounding the eigenvalues of
# feedback loops with parameters eigmin and eigmax. Values away from 1 indicates
# stronger feedback loop effects. Set values closer to 1 to apply stronger
# regularization.
#
# positional arguments:
#   fi_weight             Path of input tsv file of edge weight matrix
#   fi_covfactor          Path of iput tsv file of factors for the off-diagonal
#                         component of gene covariance matrix
#   fo_iweight            Path of output tsv file of steady-state indirect
#                         effect edge weight matrix
#
# optional arguments:
#   -h, --help            show this help message and exit
#   --norm NORM           Normalizations of indirect effect matrix. Binary flag
#                         variable that accepts: 1: Divides the indirect effect
#                         size of each TF on other genes with that on itself to
#                         obtain logFC per unit logFC of TF. 2: Accounts for
#                         mRNA saturation/sampling effects. (default: 3)
#   --fi_meanvar FI_MEANVAR
#                         Path of iput tsv file of mean and variance of each
#                         gene's relative log expression. Needed if norm & 2.
#                         (default: None)
#   --eigmin EIGMIN       Lower bound of eigenvalue for finding the minimal
#                         required extra regularization. (default: 0.2)
#   --eigmax EIGMAX       Upper bound of eigenvalue for finding the minimal
#                         required extra regularization. (default: 1.8)
#   --multiplier MULTIPLIER
#                         Step size of strengthening regularization. Larger
#                         values provide faster but over-regularization. Must be
#                         greater than 1. (default: 1.1)
#   --nth NTH             Number of threads for CPU usage. When <1, use
#                         nth*(detected core count). (default: 1)

# %% [markdown]
# ## 4.1 Aggregating network part, execution
# This part aggregates all the inferred networks into a single h5 file as output. This single file can be shared and processed by network analysis/visualization functions in Dictys.

# %%
# %%bash
# set -eo pipefail
# cd ..
# #Combine inferred networks to single h5 file
# make -f makefiles/static.mk combine
# #Optional step: Cleanup intermediate files
# make -f makefiles/static.mk clean
# Out:
# mkdir -p output/
# python3 -m dictys  network tofile  data tmp_static data/subsets.txt output/static.h5
# rm -f tmp_static/Subset1/names_rna.txt tmp_static/Subset1/names_atac0.txt tmp_static/Subset1/names_atac.txt tmp_static/Subset1/expression0.tsv.gz tmp_static/Subset1/expression.tsv.gz tmp_static/Subset1/names_atac.txt tmp_static/Subset1/reads.bam tmp_static/Subset1/reads.bai tmp_static/Subset1/peaks.bed tmp_static/Subset1/footprints.bed tmp_static/Subset1/motifs.bed tmp_static/Subset1/homer.tsv.gz tmp_static/Subset1/wellington.tsv.gz tmp_static/Subset1/binding.tsv.gz tmp_static/Subset1/tssdist.tsv.gz tmp_static/Subset1/linking.tsv.gz tmp_static/Subset1/binlinking.tsv.gz tmp_static/Subset1/net_nweight.tsv.gz tmp_static/Subset1/net_iweight.tsv.gz tmp_static/Subset1/net_inweight.tsv.gz tmp_static/Subset10/names_rna.txt tmp_static/Subset10/names_atac0.txt tmp_static/Subset10/names_atac.txt tmp_static/Subset10/expression0.tsv.gz tmp_static/Subset10/expression.tsv.gz tmp_static/Subset10/names_atac.txt tmp_static/Subset10/reads.bam tmp_static/Subset10/reads.bai tmp_static/Subset10/peaks.bed tmp_static/Subset10/footprints.bed tmp_static/Subset10/motifs.bed tmp_static/Subset10/homer.tsv.gz tmp_static/Subset10/wellington.tsv.gz tmp_static/Subset10/binding.tsv.gz tmp_static/Subset10/tssdist.tsv.gz tmp_static/Subset10/linking.tsv.gz tmp_static/Subset10/binlinking.tsv.gz tmp_static/Subset10/net_nweight.tsv.gz tmp_static/Subset10/net_iweight.tsv.gz tmp_static/Subset10/net_inweight.tsv.gz tmp_static/Subset11/names_rna.txt tmp_static/Subset11/names_atac0.txt tmp_static/Subset11/names_atac.txt tmp_static/Subset11/expression0.tsv.gz tmp_static/Subset11/expression.tsv.gz tmp_static/Subset11/names_atac.txt tmp_static/Subset11/reads.bam tmp_static/Subset11/reads.bai tmp_static/Subset11/peaks.bed tmp_static/Subset11/footprints.bed tmp_static/Subset11/motifs.bed tmp_static/Subset11/homer.tsv.gz tmp_static/Subset11/wellington.tsv.gz tmp_static/Subset11/binding.tsv.gz tmp_static/Subset11/tssdist.tsv.gz tmp_static/Subset11/linking.tsv.gz tmp_static/Subset11/binlinking.tsv.gz tmp_static/Subset11/net_nweight.tsv.gz tmp_static/Subset11/net_iweight.tsv.gz tmp_static/Subset11/net_inweight.tsv.gz tmp_static/Subset12/names_rna.txt tmp_static/Subset12/names_atac0.txt tmp_static/Subset12/names_atac.txt tmp_static/Subset12/expression0.tsv.gz tmp_static/Subset12/expression.tsv.gz tmp_static/Subset12/names_atac.txt tmp_static/Subset12/reads.bam tmp_static/Subset12/reads.bai tmp_static/Subset12/peaks.bed tmp_static/Subset12/footprints.bed tmp_static/Subset12/motifs.bed tmp_static/Subset12/homer.tsv.gz tmp_static/Subset12/wellington.tsv.gz tmp_static/Subset12/binding.tsv.gz tmp_static/Subset12/tssdist.tsv.gz tmp_static/Subset12/linking.tsv.gz tmp_static/Subset12/binlinking.tsv.gz tmp_static/Subset12/net_nweight.tsv.gz tmp_static/Subset12/net_iweight.tsv.gz tmp_static/Subset12/net_inweight.tsv.gz tmp_static/Subset13/names_rna.txt tmp_static/Subset13/names_atac0.txt tmp_static/Subset13/names_atac.txt tmp_static/Subset13/expression0.tsv.gz tmp_static/Subset13/expression.tsv.gz tmp_static/Subset13/names_atac.txt tmp_static/Subset13/reads.bam tmp_static/Subset13/reads.bai tmp_static/Subset13/peaks.bed tmp_static/Subset13/footprints.bed tmp_static/Subset13/motifs.bed tmp_static/Subset13/homer.tsv.gz tmp_static/Subset13/wellington.tsv.gz tmp_static/Subset13/binding.tsv.gz tmp_static/Subset13/tssdist.tsv.gz tmp_static/Subset13/linking.tsv.gz tmp_static/Subset13/binlinking.tsv.gz tmp_static/Subset13/net_nweight.tsv.gz tmp_static/Subset13/net_iweight.tsv.gz tmp_static/Subset13/net_inweight.tsv.gz tmp_static/Subset14/names_rna.txt tmp_static/Subset14/names_atac0.txt tmp_static/Subset14/names_atac.txt tmp_static/Subset14/expression0.tsv.gz tmp_static/Subset14/expression.tsv.gz tmp_static/Subset14/names_atac.txt tmp_static/Subset14/reads.bam tmp_static/Subset14/reads.bai tmp_static/Subset14/peaks.bed tmp_static/Subset14/footprints.bed tmp_static/Subset14/motifs.bed tmp_static/Subset14/homer.tsv.gz tmp_static/Subset14/wellington.tsv.gz tmp_static/Subset14/binding.tsv.gz tmp_static ...

# %% [markdown]
# ## 4.2 Aggregating network part, command description
# ### network tofile
# This command aggregates all inferred networks to a single output file.

# %%
# !python3 -m dictys network tofile -h
# Out:
# usage: dictys network tofile [-h] [--dynamic] [--nettype NETTYPE]
#                              [--optional OPTIONAL] [--fi_c FI_C]
#                              diri_data diri_work fi_subsets fo_networks
#
# Saving networks to a single file.
#
# positional arguments:
#   diri_data            Path of input data folder to load from
#   diri_work            Path of input working folder to load from
#   fi_subsets           Path of input txt file for cell subset names
#   fo_networks          Path of output h5 file for all networks
#
# optional arguments:
#   -h, --help           show this help message and exit
#   --dynamic            Whether to load a dynamic network instead of a set of
#                        static networks (default: False)
#   --nettype NETTYPE    Type of network. Accepts: '': Unnormalized direct
#                        network 'n': Normalized direct network 'i':
#                        Unnormalized steady-state network 'in': Normalized
#                        steady-state network (default: n)
#   --optional OPTIONAL  Optional data to include. Accepts: readcount: RNA read
#                        count for each cell (default: readcount)
#   --fi_c FI_C          Path of input tsv file for extra property columns for
#                        each cell (default: None)
